# %% [markdown]
# # Определение стоимости автомобилей

# %% [markdown]
# Сервис по продаже автомобилей с пробегом разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В работе мы построим модель для определения стоимости.
#
# В вашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей.
#
# Сервису, как заказчику, важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Импорт библиотек

# %% [markdown]
# Перед началом исследования импортируем необходимые библиотеки, а также модели.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import scale
from sklearn.preprocessing import OrdinalEncoder



from catboost import CatBoostRegressor
from sklearn.tree import  DecisionTreeRegressor
from lightgbm import LGBMRegressor

# %% [markdown]
# ### Обзор данных

# %%
data = pd.read_csv('/datasets/autos.csv') # загружаем датасет в переменную data

# %%
data.head(10)                             # первые 10 строчек
# Out:
#            DateCrawled  Price  VehicleType  RegistrationYear Gearbox  Power  \
# 0  2016-03-24 11:52:17    480          NaN              1993  manual      0
# 1  2016-03-24 10:58:45  18300        coupe              2011  manual    190
# 2  2016-03-14 12:52:21   9800          suv              2004    auto    163
# 3  2016-03-17 16:54:04   1500        small              2001  manual     75
# 4  2016-03-31 17:25:20   3600        small              2008  manual     69
# 5  2016-04-04 17:36:23    650        sedan              1995  manual    102
# 6  2016-04-01 20:48:51   2200  convertible              2004  manual    109
# 7  2016-03-21 18:54:38      0        sedan              1980  manual     50
# 8  2016-04-04 23:42:13  14500          bus              2014  manual    125
# 9  2016-03-17 10:53:50    999        small              1998  manual    101
#
#      Model  Kilometer  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0     golf     150000                  0    petrol  volkswagen         NaN
# 1      NaN     125000                  5  gasoline        audi         yes
# 2    grand     125000                  8  gasoline        jeep         NaN
# 3     golf     150000                  6    petrol  volkswagen          no
# 4    fabia      90000                  7  gasoline       skoda          no
# 5      3er     150000                 10    petrol         bmw         yes
# 6  2_reihe     150000                  8    petrol     peugeot          no
# 7    other      40000                  7    petrol  volkswagen          no
# 8    c_max      30000                  8    petrol        ford         NaN
# 9     golf     150000                  0       NaN  volkswagen         NaN
#
#            DateCreated  NumberOfPictures  PostalCode             LastSeen
# 0  2016-03-24 00:00:00                 0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00                 0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00                 0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00                 0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00                 0       60437  2016-04-06 10:17:21
# 5  2016-04-04 00:00:00                 0       33775  2016-04-06 19:17:07
# 6  2016-04-01 00:00:00                 0       67112  2016-04-05 18:18:39
# 7  2016-03-21 00:00:00                 0       19348  2016-03-25 16:47:58
# 8  2016-04-04 00:00:00                 0       94505  2016-04-04 23:42:13
# 9  2016-03-17 00:00:00                 0       27472  2016-03-31 17:17:06

# %% [markdown]
# В датасете 15 столбцов (признаков):
#
# - `DateCrawled` — дата, когда анкета скачена из базы;
# - `Price` — цена продажи — целевой признак;
# - `VehicleType` — тип автомобильного кузова;
# - `RegistrationYear`— год регистрации автомобиля;
# - `Gearbox` — тип коробки передач;
# - `Power` — мощность в лошадиных силах;
# - `Model` — модель машины;
# - `Kilometer` — пробег в км;
# - `RegistrationMonth` — месяц регистрации автомобиля;
# - `FuelType` — тип топлива;
# - `Brand` — марка автомобиля;
# - `NotRepaired` — была машина в ремонте или нет;
# - `DateCreated` — дата создания анкеты;
# - `NumberOfPictures` — количество фотографий;
# - `PostalCode` — почтовый индекс владельца автомобиля;
# - `LastSeen` — дата последней активности пользователя.

# %%
data.info()                          #общая информация по датасету
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Kilometer          354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %% [markdown]
# В датасете более 350 000 объектов — достаточно большой объем. В некоторых столбцах-признаках имеются пропуски. Кроме того, много признаков являются категориальными — понадобится приобразовать их в численные для обучения моделей.

# %%
data.describe() #агрегированные данные по численным признакам
# Out:
#                Price  RegistrationYear          Power      Kilometer  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %% [markdown]
# Из агрегированных данных видно, что в столбце `Price` минимальное значение равно 0 — потребуется далее рассмотреть данные объекты. Интересные минимумы и максимумы в `RegistrationYear` и `Power`. Признак `NumberOfPictures` судя по всему был выгружен с ошибкой — он пустой.

# %% [markdown]
# ### Проверка на явные дубликаты

# %%
data.duplicated().sum()
# Out:
# 4

# %% [markdown]
# Незначительное количество объектов в датасете задублированно — их стоит удалить, чтобы модель не переобучилась.

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Удаление неинформативных признаков

# %% [markdown]
# От даты выгрузки анкеты конечная цена автомобиля не зависит — этот признак не является информативным и его можно удалить.

# %%
data = data.drop(columns=['DateCrawled'])

# %% [markdown]
# Формально и дата, когда объявление о продаже было опубликовано, не должна влиять на цену автомобиля. Однако, если в датасете присутствуют объявления за разные годы, то на цене может сказаться инфляция. Проверим за какой период мы имеем объявления.

# %%
data['DateCreated'] = pd.to_datetime(data['DateCreated'], format='%Y-%m-%d %H:%M:%S') # меняем тип данных
                                                                                      # для удобства обработки

# %%
data['DateCreated'].dt.year.value_counts()                                            # посчитаем количесвто объектов по годам
# Out:
# 2016    354339
# 2015        25
# 2014         1
# Name: DateCreated, dtype: int64

# %% [markdown]
# В датасете всего 26 объектов не за 2016 год. Посмотрим на них:

# %%
data[data['DateCreated'].dt.year == 2014]                                             # выводим единственный объект за 2014 год
# Out:
#        Price VehicleType  RegistrationYear Gearbox  Power Model  Kilometer  \
# 61207   8999         NaN              2005     NaN      0   147     125000
#
#        RegistrationMonth FuelType       Brand NotRepaired DateCreated  \
# 61207                  0   petrol  alfa_romeo         NaN  2014-03-10
#
#        NumberOfPictures  PostalCode             LastSeen
# 61207                 0       79669  2016-04-07 04:46:24

# %% [markdown]
# **Alfa Romeo** не самая популярная машина на рынке — а марка определенно влияет на цену. Если модель поймет это, пробуя спрогнозировать цену для итальнцев по цене 2014 года, точно ошибемся с прогнозом:

# %%
data[data['Brand']== 'alfa_romeo']
# Out:
#         Price  VehicleType  RegistrationYear Gearbox  Power   Model  \
# 80        250        wagon              2000  manual    155     156
# 138      3450        sedan              2007  manual    120     147
# 412     13950        other              2011  manual    140     NaN
# 422      3200  convertible              2001  manual    150  spider
# 474      2990        sedan              2006  manual    105     147
# ...       ...          ...               ...     ...    ...     ...
# 353947   3800        sedan              2003  manual    166     156
# 353953   1450        wagon              2005  manual    175     156
# 354102   3950        coupe              2006  manual    166   other
# 354105    750        sedan              1998  manual    190     156
# 354361   5250          NaN              2016    auto    150     159
#
#         Kilometer  RegistrationMonth  FuelType       Brand NotRepaired  \
# 80         150000                  0    petrol  alfa_romeo         yes
# 138        150000                  4  gasoline  alfa_romeo          no
# 412         60000                 11  gasoline  alfa_romeo          no
# 422        150000                  6       NaN  alfa_romeo         NaN
# 474        150000                  6    petrol  alfa_romeo          no
# ...           ...                ...       ...         ...         ...
# 353947     125000                  7    petrol  alfa_romeo          no
# 353953     150000                  7  gasoline  alfa_romeo          no
# 354102     150000                  5    petrol  alfa_romeo          no
# 354105     150000                 10    petrol  alfa_romeo          no
# 354361     150000                 12       NaN  alfa_romeo          no
#
#        DateCreated  NumberOfPictures  PostalCode             LastSeen
# 80      2016-04-01                 0        8396  2016-04-05 20:18:14
# 138     2016-04-02                 0       86678  2016-04-04 07:51:11
# 412     2016-03-26                 0       86830  2016-04-06 14:15:39
# 422     2016-03-21                 0       24939  2016-03-31 08:18:09
# 474     2016-03-30                 0       74912  2016-04-07 09:44:33
# ...            ...               ...         ...                  ...
# 353947  2016-04-03                 0       50827  2016-04-05 17:45:54
# 353953  2016-03-05                 0       97082  2016-03-17 05:15:16
# 354102  2016-03-19                 0       59174  2016-03-29 03:15:54
# 354105  2016-03-31                 0       27568  2016-04-06 13:15:43
# 354361  2016-03-09                 0       51371  2016-03-13 01:44:13
#
# [2314 rows x 15 columns]

# %% [markdown]
# Из 15 объектов один будет выбросом.

# %%
data[data['DateCreated'].dt.year == 2015]
# Out:
#         Price  VehicleType  RegistrationYear Gearbox  Power     Model  \
# 4001     6000          bus              1995    auto    200     other
# 9972     3490        sedan              2006  manual     88      clio
# 29712    6950        sedan              2004    auto    150        a3
# 60168    5999        sedan              1997    auto    197  c_klasse
# 75598     600        small              2005  manual     54      polo
# 75684    5400        small              2009  manual     44   ypsilon
# 76459    7500        sedan              2002    auto    333       7er
# 77378    7999        sedan              2013  manual     75       mii
# 85505     900        sedan              1997    auto    115   impreza
# 86601   14250  convertible              2005  manual    163       slk
# 125286   7999        sedan              2013  manual     75       mii
# 153650  11999          NaN              2008  manual    150       NaN
# 161567  15500        wagon              2009  manual    160        a4
# 175103   5200  convertible              2006  manual    109   2_reihe
# 221002    600        small              2005  manual     54      polo
# 226822    900        sedan              1997    auto    115   impreza
# 244633   2400        sedan              2004    auto     61    fortwo
# 260635    900        sedan              1997    auto    115   impreza
# 274600   9999        wagon              2006    auto    140        a4
# 282938   5499        sedan              2009  manual     95   2_reihe
# 301180   5900  convertible              1995  manual     90  mx_reihe
# 340616   9500        small              2013  manual     90     corsa
# 342275  10400          bus              1993     NaN      0    ducato
# 343447  18500        sedan              2015  manual    110      golf
# 344287  17200  convertible              1985    auto    155        sl
#
#         Kilometer  RegistrationMonth  FuelType          Brand NotRepaired  \
# 4001       150000                  0    petrol      chevrolet          no
# 9972       150000                  3    petrol        renault          no
# 29712      100000                  1    petrol           audi          no
# 60168      150000                  9    petrol  mercedes_benz          no
# 75598      150000                  1    petrol     volkswagen         yes
# 75684       40000                  9    petrol         lancia          no
# 76459      150000                  9       lpg            bmw          no
# 77378       30000                  6    petrol           seat          no
# 85505      150000                  4    petrol         subaru          no
# 86601      150000                  6    petrol  mercedes_benz          no
# 125286      30000                  6    petrol           seat          no
# 153650      90000                  1  gasoline           opel          no
# 161567     100000                 11    petrol           audi          no
# 175103      80000                 11    petrol        peugeot          no
# 221002     150000                  1    petrol     volkswagen         yes
# 226822     150000                  4    petrol         subaru          no
# 244633      90000                  6    petrol          smart          no
# 260635     150000                  4    petrol         subaru          no
# 274600     150000                  5  gasoline           audi          no
# 282938      70000                  3    petrol        peugeot          no
# 301180     125000                  5    petrol          mazda         NaN
# 340616      50000                  4  gasoline           opel          no
# 342275      30000                  1  gasoline           fiat         NaN
# 343447      10000                  3    petrol     volkswagen          no
# 344287     150000                  2    petrol  mercedes_benz         NaN
#
#        DateCreated  NumberOfPictures  PostalCode             LastSeen
# 4001    2015-03-20                 0       24558  2016-04-07 03:45:01
# 9972    2015-11-02                 0       40880  2016-03-17 15:46:57
# 29712   2015-12-06                 0       61389  2016-04-06 14:16:09
# 60168   2015-11-17                 0       28816  2016-04-06 05:46:03
# 75598   2015-09-04                 0       72669  2016-03-15 14:16:58
# 75684   2015-11-12                 0       53119  2016-04-06 03:16:57
# 76459   2015-12-27                 0       46117  2016-03-27 22:15:37
# 77378   2015-11-24                 0       60437  2016-04-05 22:47:33
# 85505   2015-12-05                 0        2943  2016-03-22 23:16:25
# 86601   2015-08-07                 0       76228  2016-04-07 09:15:23
# 125286  2015-11-24                 0       60437  2016-04-07 11:25:36
# 153650  2015-11-23                 0        7749  2016-03-27 17:44:16
# 161567  2015-11-08                 0       56410  2016-04-06 23:15:36
# 175103  2015-08-10                 0       26382  2016-04-05 20:46:54
# 221002  2015-09-04                 0       72669  2016-03-15 15:49:29
# 226822  2015-12-05                 0        2943  2016-03-22 20:16:42
# 244633  2015-12-30                 0       10315  2016-04-06 15:17:11
# 260635  2015-12-05                 0        2943  2016-03-23 13:56:25
# 274600  2015-12-17                 0       89275  2016-04-05 12:45:51
# 282938  2015-11-10                 0       22941  2016-04-07 09:15:21
# 301180  2015-11-23                 0       63741  2016-03-23 07:18:38
# 340616  2015-09-09                 0       98739  2016-04-05 17:46:04
# 342275  2015-06-18                 0       76275  2016-04-05 17:46:09
# 343447  2015-12-30                 0       22391  2016-04-07 07:15:41
# 344287  2015-12-30                 0       75177  2016-04-05 12:44:49

# %% [markdown]
# Большинство имеющихся объявлений за 2015 год созданы в ноябре или декабре и должны уже учитывать инфляцию за первые кварталы года, однако, т.к. они составляют незначительное долю от общего датасета (`25 / 354 335 = 0,00007 %`) их можно удалить.

# %%
data = data[data['DateCreated'].dt.year == 2016]    # оставляем объекты за 2016 год
data = data.drop(columns=['DateCreated'])           # а после удаляем столбец с датой создания объявления

# %% [markdown]
# Интересный вопрос, влияет ли месяц регистрации транспортного средства на его цену — формально его "новизну" определяет пробег, а не дата регистрации, но в зависимости от месяца мы можем предполагать поколение популярных моделей — а это точно ценообразующий фактор. Например, **Mitsubishi Outlander III поколения** выпускался с 2012 по сентябрь 2014, а в октябре была представлена версия **рестайлинг** — изменились передние и задние бампера, решётка радиатора, появились расширители арок, поменялась задняя оптика, появились светодиоды и новые 18-дюймовые колёсные диски, улучшилась шумоизоляция салона, система охлаждения вариатора, была перенастроена подвеска.

# %% [markdown]
# Ранее мы заметили ошибку в признаке `NumberOfPictures` — все квартили и максимум равнялись нулю. Проверим заполнение признака, посчитав уникальные значения в столбце.

# %%
data['NumberOfPictures'].value_counts()
# Out:
# 0    354339
# Name: NumberOfPictures, dtype: int64

# %% [markdown]
# Этот признак, а также информацию об авторе объявления (`PostalCode` и `LastSeen`) мы удалим, так как они не влияют на цену транспортного средства.

# %%
data = data.drop(columns=['NumberOfPictures','PostalCode','LastSeen'])

# %% [markdown]
# Посмотрим на информацию по датасету после удаления неинформативных столбцов

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354339 entries, 0 to 354368
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Price              354339 non-null  int64
#  1   VehicleType        316851 non-null  object
#  2   RegistrationYear   354339 non-null  int64
#  3   Gearbox            334508 non-null  object
#  4   Power              354339 non-null  int64
#  5   Model              334635 non-null  object
#  6   Kilometer          354339 non-null  int64
#  7   RegistrationMonth  354339 non-null  int64
#  8   FuelType           321444 non-null  object
#  9   Brand              354339 non-null  object
#  10  NotRepaired        283189 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 32.4+ MB

# %% [markdown]
# Т. о. у нас осталось 11 признаков (один из которых целевой).

# %% [markdown]
# ### Обработка пропусков и аномалий

# %% [markdown]
# #### Аномалии в целевом признаке

# %% [markdown]
# В начале исследования мы заметили, что целевой признак `Price` имеет минимальное значение 0. Посмотрим на распределение значений этого признака:

# %%
data['Price'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Кажется, большинство автомобилей в датасете достаточно дешевые — пик распределения цены где-то около 1000 евро (при этом среднее равняется 4416, а медиана — 2700).

# %% [markdown]
# Посмотрим на автомобили без указания цены:

# %%
data[data['Price']==0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10772 entries, 7 to 354364
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Price              10772 non-null  int64
#  1   VehicleType        7032 non-null   object
#  2   RegistrationYear   10772 non-null  int64
#  3   Gearbox            8294 non-null   object
#  4   Power              10772 non-null  int64
#  5   Model              8588 non-null   object
#  6   Kilometer          10772 non-null  int64
#  7   RegistrationMonth  10772 non-null  int64
#  8   FuelType           7336 non-null   object
#  9   Brand              10772 non-null  object
#  10  NotRepaired        5484 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 1009.9+ KB

# %%
data[data['Price']==0].head(10)
# Out:
#      Price VehicleType  RegistrationYear Gearbox  Power   Model  Kilometer  \
# 7        0       sedan              1980  manual     50   other      40000
# 40       0         NaN              1990     NaN      0   corsa     150000
# 111      0         NaN              2017  manual      0    golf       5000
# 115      0       small              1999     NaN      0     NaN       5000
# 152      0         bus              2004  manual    101  meriva     150000
# 154      0         NaN              2006     NaN      0   other       5000
# 231      0       wagon              2001  manual    115  mondeo     150000
# 334      0         NaN              2005     NaN      0    polo     150000
# 415      0         NaN              1985     NaN      0     3er     150000
# 466      0         NaN              2016    auto    197     3er     150000
#
#      RegistrationMonth  FuelType       Brand NotRepaired
# 7                    7    petrol  volkswagen          no
# 40                   1    petrol        opel         NaN
# 111                 12    petrol  volkswagen         NaN
# 115                  0    petrol  volkswagen         NaN
# 152                 10       lpg        opel         yes
# 154                  0       NaN        fiat         NaN
# 231                  0       NaN        ford         NaN
# 334                  0    petrol  volkswagen         NaN
# 415                  0       NaN         bmw         NaN
# 466                 12  gasoline         bmw          no

# %% [markdown]
# Почти 11 000 объектов — возможно это автомобили на разборке, продающиеся на запчасти, возможно автомобили на заказ, которые "пригонят" из другой страны (у 2200 не указана конкретная марка), возможно, авторы объявления оставили цену открытой для торга. Так или иначе, обучить по ним модель и предсказать цену для новых объявлений не получится — **удалим эти объекты из датасета**.

# %%
data = data[data['Price']!=0]

# %% [markdown]
# #### Аномалии в годе регистрации ТС

# %%
data['RegistrationYear'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# График делают непригодным аномальные значения — минимум составляет 1000 год, а максимум 9999. Нормальными очевидно могут является годы с 1908 (появление первого массового автомобиля Ford T — хотя вряд ли такие старые машины есть в датасете) по 2016 (т.к. все анкеты опубликованы в 2016).

# %%
data = data[data['RegistrationYear'] > 1908]# отбрасываем значения с годом регистрации меньше адекватного

# %% [markdown]
# Автомобили, с датой регистрации позже выгрузки датасета, следует сначала рассмотреть — возможно это предпродажа будущих моделей.

# %%
data[data['RegistrationYear'] > 2016].describe()
# Out:
#               Price  RegistrationYear         Power      Kilometer  \
# count  13779.000000      13779.000000  13779.000000   13779.000000
# mean    3324.007185       2043.060091     89.073735  131936.642717
# std     3470.907197        384.355937    252.706240   36573.752919
# min        1.000000       2017.000000      0.000000    5000.000000
# 25%     1050.000000       2017.000000      0.000000  125000.000000
# 50%     2000.000000       2017.000000     80.000000  150000.000000
# 75%     4250.000000       2018.000000    117.000000  150000.000000
# max    20000.000000       9999.000000  16011.000000  150000.000000
#
#        RegistrationMonth
# count       13779.000000
# mean            4.807969
# std             3.994933
# min             0.000000
# 25%             1.000000
# 50%             4.000000
# 75%             8.000000
# max            12.000000

# %% [markdown]
# Вероятно, часть объектов действительно относится к такого рода объявлениям, однако средняя цена 3324 евро явно меньше цены нового автомобиля. Т.к. возможности рассматривать каждое из 13779 объявления в ручную нет возможности, признаем такие объекты аномальными и также отбросим их.

# %%
data = data[data['RegistrationYear'] <= 2016]

# %%
data['RegistrationYear'].hist(bins=50) # распределение после удаления аномалий
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Пропуски и аномалии в типах автомобильного кузова

# %% [markdown]
# Сначала посмотрим какие значения имеюся по данному признаку:

# %%
data['VehicleType'].value_counts()
# Out:
# sedan          89389
# small          78009
# wagon          63694
# bus            28341
# convertible    19860
# coupe          15632
# suv            11790
# other           3085
# Name: VehicleType, dtype: int64

# %% [markdown]
# Нетипичных значений и смысловых синонимов нет. Теперь перейдем к пропускам:

# %%
data['VehicleType'].isna().sum()
# Out:
# 19935

# %% [markdown]
# Т. к. одна и та же модель может выпускать в разных типах кузова, заменить пропуски по названию модели не получится.

# %%
data[data['Model']=='golf']['VehicleType'].hist() #распределение типов кузова для гольфов
# Out:
# <AxesSubplot:>

# %% [markdown]
# Чтобы при дальнейшей обработке данных не потерять строки с пропусками заменим `NaN` на новое значение **undefined**

# %%
data['VehicleType'] = data['VehicleType'].fillna('undefined')

# %% [markdown]
# #### Обработка пропусков и аномалий по коробкам передач

# %%
data['Gearbox'].value_counts()
# Out:
# manual    251144
# auto       62991
# Name: Gearbox, dtype: int64

# %% [markdown]
# В датасете представлено два типа значений для коробки передач - коробки автомат не делятся на типы (автомат, робот, вариатор).

# %%
data.pivot_table(index=['Gearbox'],
                 values=['Price'],
                 aggfunc=['mean'])
# Out:
#                 mean
#                Price
# Gearbox
# auto     7048.216031
# manual   4123.514458

# %% [markdown]
# Тип коробки передач сильно влияет на цену автомобиля ("автоматы" дороже). Можно попробовать "восстановить" пропуски, сравнив цену со средней для марки текущего года - если она ближе к цене "механики" заполнить "manual", а если к цене "автомата" — "auto".

# %%
data.pivot_table(index=['Gearbox'],
                 columns=['Model','RegistrationYear'],
                 values=['Price'],
                 aggfunc=['mean'])
# Out:
#                     mean                                               \
#                    Price
# Model                100
# RegistrationYear    1970    1972         1973    1974    1975    1976
# Gearbox
# auto              2800.0     NaN          NaN     NaN     NaN     NaN
# manual               NaN  7530.0  4463.333333  7000.0  3650.0  4224.5
#
#                                                    ...               \
#                                                    ...
# Model                                              ...       zafira
# RegistrationYear     1978   1979     1980    1982  ...         2007
# Gearbox                                            ...
# auto               2999.0    NaN  15000.0  8000.0  ...  5644.080000
# manual            14950.0  850.0   6500.0  2900.0  ...  5300.467456
#
#                                                                       \
#
# Model
# RegistrationYear         2008         2009         2010         2011
# Gearbox
# auto              6142.483871  6360.571429  9018.888889          NaN
# manual            6498.340206  6973.151515  9241.521739  9152.757143
#
#                                                                      \
#
# Model
# RegistrationYear          2012          2013     2014          2015
# Gearbox
# auto              14950.000000  16925.000000      NaN           NaN
# manual            11401.814815  13203.333333  14902.9  15466.666667
#
#
#
# Model
# RegistrationYear         2016
# Gearbox
# auto              1275.000000
# manual            2918.366197
#
# [2 rows x 4573 columns]

# %% [markdown]
# С такой логикой возникли проблемы — для некоторых моделей нет данных по цене за определенные годы, а на примере "zafira" мы видим, что цена может и почти не отличаться (у моделей 2008,2009,2010 годов с разными коробками почти одинаковая цена)

# %% [markdown]
# Поступим с пропусками в признаке "Gearbox" аналогично пропускам в "VehicleType" — **заменим пропуски на новое значение undefined**, чтобы объекты с пропусками не потерялись при дальнейшей обработке и группировках.

# %%
data['Gearbox'] = data['Gearbox'].fillna('undefined')

# %% [markdown]
# #### Пропуски и аналомалии по мощности двигателя.

# %% [markdown]
# Известное выражение (то ли Генри Форда, то ли Энзо Феррари) — "лошадиные силы продают автомобиль, а крутящий момент выигрывает гонки". Мощность двигателя действительно влияет на цену автомобиля. Посмотрим на распределение по этому параметру.

# %%
data['Power'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# График получается неинформативным. При среднем значении в 110 л.с. в датасете есть объекты со значением в 20 000 л.с.
#
# В качестве границы нормальных значений установим 1000 л.с. — хотя сегодня есть суперкары и по 1500 л.с. такие объекты не будут типичными.

# %%
data = data[data['Power'] <= 1000]

# %%
data['Power'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# График растянут вправо из-за сохранившихся крайних значений. Однако, уже после примерно 600 л.с. мы не видим рисунка диаграммы из-за незначительного количества объектов.

# %%
data[data['Power'] > 600] #посмотрим на объекты
# Out:
#         Price VehicleType  RegistrationYear    Gearbox  Power    Model  \
# 4060     3100       sedan              2005     manual    953     colt
# 6296      599       small              2002     manual    603    matiz
# 6504     3000       small              2009     manual    771    punto
# 6637      600       small              1996     manual    603    corsa
# 8057      500       small              2002     manual    620  ypsilon
# ...       ...         ...               ...        ...    ...      ...
# 317353   3999       small              2009     manual    682      NaN
# 320442   3400       small              2007  undefined    732      NaN
# 328668    599       small              2002     manual    603    matiz
# 331252   4600       small              2008     manual    601     polo
# 353633   2400       sedan              2007     manual    650       c2
#
#         Kilometer  RegistrationMonth  FuelType       Brand NotRepaired
# 4060       150000                  4  gasoline  mitsubishi          no
# 6296         5000                 11    petrol   chevrolet         yes
# 6504       125000                  0    petrol        fiat         NaN
# 6637       150000                  8    petrol        opel         yes
# 8057       150000                 12    petrol      lancia         NaN
# ...           ...                ...       ...         ...         ...
# 317353      70000                  1    petrol     peugeot          no
# 320442     125000                 12    petrol     citroen          no
# 328668       5000                 11    petrol   chevrolet         yes
# 331252      80000                  1    petrol  volkswagen          no
# 353633     150000                  8    petrol     citroen         NaN
#
# [68 rows x 11 columns]

# %% [markdown]
# Никаких суперкаров — chevrolet matiz c 600 л.с. (при стоке 52 л.с.), volkswagen polo с 601 л.с. — объявления больше похожи на ошибочные или мошеннические. Удалим их как аномалии. Граница в 600 л.с. позволит оставить в датасете настоящие суперкары (например, Ford Mustang GT).
#
# В качестве левой границы установим 20 л.с. — такую мощность имел уже упоминаемый нами Ford T.

# %%
#отбрасываем крайние значения и смотрим на новое распределение

data = data[(data['Power'] > 24)&(data['Power'] < 600)]
data['Power'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Проверка значений по признаку `Model`

# %% [markdown]
# В датасете имеются пропуски по признаку `Model`. Восстановить их не представляется возможным, а модель — важнейший ценообразующий фактор — модели одного бренда могут быть несопоставимы по стоимости (например, Ford Focus и Ford Mustang).
#
# По этой причине, объекты с пропусками придется отбросить.

# %%
data.dropna(subset=['Model'], inplace=True)

# %% [markdown]
# #### Проверка пробега

# %%
data['Kilometer'].isna().sum() #проверка пропусков
# Out:
# 0

# %%
data['Kilometer'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Кажется, аномалий нет — за исключением почти отсутствующих значений с промежутке 105 000 - 120 000. В датасете преобладают старые "тачки" и для них характерен большой пробег — как раз такую картину мы и видим.

# %% [markdown]
# #### Обработка признака Brand

# %% [markdown]
# Сначала проверим датасет на наличие неявных дубликатов (например, если автор объявления опечатался):

# %%
data.Brand.value_counts()
# Out:
# volkswagen       62045
# opel             31390
# bmw              31150
# mercedes_benz    26687
# audi             24881
# ford             20148
# renault          13500
# peugeot           8894
# fiat              7315
# seat              5720
# skoda             4865
# mazda             4530
# smart             4347
# citroen           4108
# nissan            3924
# toyota            3913
# hyundai           2987
# mini              2927
# volvo             2753
# mitsubishi        2396
# honda             2274
# kia               2014
# alfa_romeo        1905
# suzuki            1891
# chevrolet         1396
# chrysler          1116
# dacia              787
# subaru             622
# porsche            610
# daihatsu           600
# jeep               563
# saab               464
# land_rover         454
# jaguar             431
# daewoo             385
# lancia             364
# rover              322
# trabant            241
# lada               151
# Name: Brand, dtype: int64

# %% [markdown]
# Неявные дубликаты не выявлены.
# Теперь посмотрим на график цены по брендам.

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=data, x='Brand', y='Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Разброс цен большой — у многих брендов имеется значительно количество "выбросов", которые продавались дороже рынка. Что важно — мы не наблюдаем дорогих daewoo, lada и daihatsu, и видим дорогие porsche и land rover'ы, что кажется логичным.

# %% [markdown]
# #### Обработка признака `FuelType`

# %%
data.FuelType.value_counts()
# Out:
# petrol      181138
# gasoline     85894
# lpg           4418
# cng            467
# hybrid         180
# other           67
# electric        36
# Name: FuelType, dtype: int64

# %% [markdown]
# Помимо традионных бензина и дизеля в датасете еще имеются электрокары, гибриды и машины на газу несольких типов.
#
# 1.CNG (Compressed Natural Gas) – сжатый природный газ (метан): газообразные углеводороды, образующиеся в земной коре, высокоэкономичное энергетическое топливо.
#
# 2.LPG (Liquified Petroleum Gas) – сжиженный газ (пропан-бутан). Газ, полученный при добыче и переработке нефти. В жидкое состояние переводят при охлаждении до критической температуры и последующей конденсации в результате отвода теплоты парообразования.

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.boxplot(data=data, x='FuelType', y='Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Видно, что гибриды и электрокары как правило дороже — это наши нового поколения. Взглянем на пропуски по признаку:

# %%
data.FuelType.isna().sum()
# Out:
# 12870

# %% [markdown]
# Заполним пропуски уже имеющимся значение `other` — так мы не потеряем объекты.

# %%
data['FuelType'] = data['FuelType'].fillna('other')

# %% [markdown]
# #### Обработка признака "NotRepaired"

# %% [markdown]
# Последний оставшийся признак `NotRepaired` — была ли машина в ремонте.

# %%
data.NotRepaired.value_counts() #значения
# Out:
# no     218533
# yes     27424
# Name: NotRepaired, dtype: int64

# %%
data.NotRepaired.isna().sum() #количество пропусков
# Out:
# 39113

# %% [markdown]
# Почти у 40 тысяч оставшихся объектов нет информации, была ли машина в ремонте, — это большая доля датасета. Заменим признак для новых машин (до 3 лет) на `no`, и для более старых на `yes`. Для этого напишем функцию.

# %%
def get_repaired(row):
    """
    Функция проверит год регистрации автомобиля. Если автомобиль зарегистирован до 2013 года и нет информации о ремонте,
    мы предположим, что автомобиль уже был отремонтирован в силу возраста.Если автомобиль не старше 3 лет (предполагается,
    что объекты в датасете датируются 2016 годом), и нет информации о ремонте, то мы предположим, что в ремонте он не был.
    
    Новый признак получит булев тип.
    """
    
    if row['RegistrationYear'] <= 2013:
        if row['NotRepaired'] == 'no':
            return False
        elif row['NotRepaired'] == 'yes':
            return True
        else:
            return True
    else:
        if row['NotRepaired'] == 'no':
            return False
        elif row['NotRepaired'] == 'yes':
            return True
        else:
            return False

# %%
data['WasRepaired'] = data.apply(get_repaired, axis=1) # создаем новый признак WasRepaired с булевым типом
                                                       # на основе признака NotRepaired

# %%
data.head()
# Out:
#    Price  VehicleType  RegistrationYear Gearbox  Power    Model  Kilometer  \
# 2   9800          suv              2004    auto    163    grand     125000
# 3   1500        small              2001  manual     75     golf     150000
# 4   3600        small              2008  manual     69    fabia      90000
# 5    650        sedan              1995  manual    102      3er     150000
# 6   2200  convertible              2004  manual    109  2_reihe     150000
#
#    RegistrationMonth  FuelType       Brand NotRepaired  WasRepaired
# 2                  8  gasoline        jeep         NaN         True
# 3                  6    petrol  volkswagen          no        False
# 4                  7  gasoline       skoda          no        False
# 5                 10    petrol         bmw         yes         True
# 6                  8    petrol     peugeot          no        False

# %%
data = data.drop(columns=['NotRepaired']) #удаляем дублирующий признак

# %% [markdown]
# #### Проверка корреляций:

# %% [markdown]
# Посмотрим на наличие корреляций, между оставшимися признаками — возможно, есть линейная зависимость между признаками и какие-то являются избыточными

# %%
fig = plt.figure(figsize=(5,5))


sns.heatmap(data.corr(),
            annot = True,
            cbar=False)
plt.title('Корреляции признаков')
# Out:
# Text(0.5, 1.0, 'Корреляции признаков')

# %% [markdown]
# Как мы видим, больший вклад в цену дает год регистрации автомобиля и мощность двигателя. Большую роль играет пробег автомобиля.

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# На этапе предобработки данных были последовательно изучены и обработаны все признаки в датасете:
# - был удален неинформативный признак с датой выгрузки анкеты;
# - были отброшены объявления до 2016 года, с целью предотвратить влияние инфляции на прогнозируемый признак;
# - удален выгруженный с ошибкой признак с количеством изображений в объявлении;
# - обработаны аномалии в целевом признаке — уделаны объявления с нулевым значением цены;
# - удалены объекты с датой регистрации ТС позже 2016 года;
# - заполнены пропуски в признаках "Тип кузова"  и "Тип коробки передач";
# - удалены объявления с аномальными значениями мощности двигателя;
# - удалены объявления с отсутствующей маркой автомобиля;
# - произвеена проверка пробега автомобилей;
# - заменены пропуски в признаке "FuelType";
# - преобразован тип данных и обработаны пропуски в признаке "NotReaired"

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285070 entries, 2 to 354368
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Price              285070 non-null  int64
#  1   VehicleType        285070 non-null  object
#  2   RegistrationYear   285070 non-null  int64
#  3   Gearbox            285070 non-null  object
#  4   Power              285070 non-null  int64
#  5   Model              285070 non-null  object
#  6   Kilometer          285070 non-null  int64
#  7   RegistrationMonth  285070 non-null  int64
#  8   FuelType           285070 non-null  object
#  9   Brand              285070 non-null  object
#  10  WasRepaired        285070 non-null  bool
# dtypes: bool(1), int64(5), object(5)
# memory usage: 32.3+ MB

# %%
data = data.reset_index(drop=True) # перезапишем датасет с исправленной индексацией

# %% [markdown]
# После предобработки данных количество объектов в датасете сократилось почти на 20% с 354366 до 285070. Количество признаков уменьшено с 16 до 11, а использование памяти — с 43,3+ до 32,3+

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Разделение датасета на выборки

# %%
target = data['Price']                          # определяем целевой признак
features = data.drop('Price', axis=1)          

features_train, features_valid_test, target_train, target_valid_test = train_test_split(features,
                                                                                        target,
                                                                                        test_size=0.4,
                                                                                        random_state=1049)

# %%
features_valid, features_test, target_valid, target_test = train_test_split(features_valid_test,
                                                                            target_valid_test,
                                                                            test_size=0.5,
                                                                            random_state=1049)

# %%
features_valid.shape
# Out:
# (57014, 10)

# %%
target_valid.shape
# Out:
# (57014,)

# %% [markdown]
# ### Обучение модели решающего древа

# %% [markdown]
# Перед обучением моделей с применение бустинга, обучим регрессор по алгоритму решающего древа. Т.к. в датасете имеются категориальные признаки перед обучение модели применим технику порядкового кодирования.

# %%
cat_features=['VehicleType','Gearbox','FuelType','Brand','Model'] #определяем категориальные признаки

# %%
encoder = OrdinalEncoder()

ord_features = data.drop('Price', axis=1) .copy()

ord_features[cat_features] = encoder.fit_transform(data[cat_features])

# %%
ord_features_train = ord_features.loc[features_train.index, :]
ord_features_valid = ord_features.loc[features_valid.index, :]
ord_features_test = ord_features.loc[features_test.index, :]

# %%
ord_features_train.head()
# Out:
#         VehicleType  RegistrationYear  Gearbox  Power  Model  Kilometer  \
# 83615           8.0              2007      1.0    163   11.0     150000
# 278144          5.0              2007      1.0     54  173.0      60000
# 109362          7.0              2000      1.0    125   28.0     150000
# 56434           4.0              2007      1.0     80  116.0      90000
# 181394          5.0              2002      1.0     60  176.0      20000
#
#         RegistrationMonth  FuelType  Brand  WasRepaired
# 83615                   5       2.0    2.0        False
# 278144                  5       6.0   37.0        False
# 109362                  0       6.0    1.0         True
# 56434                   8       6.0   37.0        False
# 181394                  7       5.0    9.0         True

# %% [markdown]
# Теперь подберем лучшие гиперпараметры для решающего древа

# %%
model = DecisionTreeRegressor(random_state = 1049) #создаем объект модели

# %%
# создаем словарь с параметрами, которые переберем

parametrs = {'max_depth' : range(1,20,2),
             'min_samples_leaf': range (1,8)}

grid = GridSearchCV(model, parametrs, scoring = 'neg_mean_squared_error', cv=5)
grid.fit(ord_features_train, target_train)
grid.best_params_
# Out:
# {'max_depth': 19, 'min_samples_leaf': 7}

# %% [markdown]
# Обучим модель с лучшими параметрами и посмотрим время обучения.

# %%
# %%time
model_DTR = DecisionTreeRegressor(max_depth = 19,
                                  min_samples_leaf = 7,
                                  random_state = 1049)
model_DTR.fit(ord_features_train,target_train)
# Out:
# CPU times: user 655 ms, sys: 23.9 ms, total: 679 ms
# Wall time: 689 ms
# DecisionTreeRegressor(max_depth=19, min_samples_leaf=7, random_state=1049)

# %%
# %%time
predictions_DTR = model_DTR.predict(ord_features_valid)
mse = mean_squared_error(target_valid, predictions_DTR)
rmse = mse ** 0.5
print(rmse)
# Out:
# 1797.064309258793
# CPU times: user 66.4 ms, sys: 3.95 ms, total: 70.3 ms
# Wall time: 71.8 ms

# %% [markdown]
# Модель быстро обучаетcя и показывает неплохую метрику RMSE - хотя 1800 евро достаточно существенная ошибка для старых автомобилей, который доминируют в датасете. Кроме того, что на тестовой выборке модель может дать худший результат.

# %% [markdown]
# ### Обучение модели LightGBM

# %%
model = LGBMRegressor(random_state = 1049)                          # создаем объект модели


parametrs = {'num_leaves':[100, 150],                           # словарь, по которому переберем гиперпараметры
             'learning_rate':[0.05, 0.2, 0.4]}

grid = GridSearchCV(model, parametrs, scoring = 'neg_mean_squared_error', cv=5)
grid.fit(ord_features_train, target_train)
grid.best_params_
# Out:
# {'learning_rate': 0.2, 'num_leaves': 150}

# %% [markdown]
# Обучим модель с лучшими параметрами и посмотрим время обучения.

# %%
# %%time
model_LGR = LGBMRegressor(learning_rate = 0.2,
                          num_leaves = 150,
                          random_state = 1049)

model_LGR.fit(ord_features_train,target_train)
# Out:
# CPU times: user 7.11 s, sys: 45.9 ms, total: 7.15 s
# Wall time: 7.2 s
# LGBMRegressor(learning_rate=0.2, num_leaves=150, random_state=1049)

# %%
# %%time

predictions_LGR = model_LGR.predict(ord_features_valid)
mse = mean_squared_error(target_valid, predictions_LGR)
rmse = mse ** 0.5
print(rmse)
# Out:
# 1557.4524935517736
# CPU times: user 470 ms, sys: 10.5 ms, total: 481 ms
# Wall time: 415 ms

# %% [markdown]
# Модель обучается быстро, а метрика RMSE превосходит  Древо принятия решений.

# %% [markdown]
# ### Обучение CatBoostRegressor

# %% [markdown]
# CatBoostRegressor может напрямую работать с категориальными признаками (как и LGBMRegressor, при некоторых ухищрениях).

# %%
model = CatBoostRegressor(cat_features=cat_features, random_state = 1049)

grid = {'learning_rate': [0.03, 0.1],
        'depth': [4, 6, 10]}

grid_search_result = model.grid_search(grid, 
                                       X=features_train, 
                                       y=target_train, 
                                       plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 6561.8369007	test: 6557.4603117	best: 6557.4603117 (0)	total: 169ms	remaining: 2m 48s
# 1:	learn: 6402.8920919	test: 6397.9092725	best: 6397.9092725 (1)	total: 256ms	remaining: 2m 7s
# 2:	learn: 6248.7997827	test: 6243.2020443	best: 6243.2020443 (2)	total: 350ms	remaining: 1m 56s
# 3:	learn: 6101.0930018	test: 6094.8450380	best: 6094.8450380 (3)	total: 447ms	remaining: 1m 51s
# 4:	learn: 5958.0838398	test: 5951.3344672	best: 5951.3344672 (4)	total: 563ms	remaining: 1m 52s
# 5:	learn: 5819.1467135	test: 5812.0548408	best: 5812.0548408 (5)	total: 652ms	remaining: 1m 48s
# 6:	learn: 5685.2325200	test: 5677.4776755	best: 5677.4776755 (6)	total: 742ms	remaining: 1m 45s
# 7:	learn: 5556.5713585	test: 5548.2221410	best: 5548.2221410 (7)	total: 843ms	remaining: 1m 44s
# 8:	learn: 5431.9241022	test: 5422.3949149	best: 5422.3949149 (8)	total: 934ms	remaining: 1m 42s
# 9:	learn: 5311.7887713	test: 5301.8279085	best: 5301.8279085 (9)	total: 1.03s	remaining: 1m 42s
# 10:	learn: 5194.9653990	test: 5184.4836897	best: 5184.4836897 (10)	total: 1.13s	remaining: 1m 41s
# 11:	learn: 5083.4419968	test: 5072.5765599	best: 5072.5765599 (11)	total: 1.22s	remaining: 1m 40s
# 12:	learn: 4974.6930302	test: 4963.5331213	best: 4963.5331213 (12)	total: 1.3s	remaining: 1m 38s
# 13:	learn: 4870.1075245	test: 4858.3740992	best: 4858.3740992 (13)	total: 1.39s	remaining: 1m 38s
# 14:	learn: 4768.3325734	test: 4755.8942879	best: 4755.8942879 (14)	total: 1.5s	remaining: 1m 38s
# 15:	learn: 4669.6417690	test: 4656.6064266	best: 4656.6064266 (15)	total: 1.59s	remaining: 1m 37s
# 16:	learn: 4576.9513595	test: 4562.8577310	best: 4562.8577310 (16)	total: 1.68s	remaining: 1m 37s
# 17:	learn: 4486.0031719	test: 4471.1348436	best: 4471.1348436 (17)	total: 1.78s	remaining: 1m 37s
# 18:	learn: 4399.5666535	test: 4384.3526721	best: 4384.3526721 (18)	total: 1.89s	remaining: 1m 37s
# 19:	learn: 4313.7406499	test: 4297.3978568	best: 4297.3978568 (19)	total: 1.97s	remaining: 1m 36s
# 20:	learn: 4232.5152119	test: 4215.8531632	best: 4215.8531632 (20)	total: 2.07s	remaining: 1m 36s
# 21:	learn: 4153.7250554	test: 4138.6279605	best: 4138.6279605 (21)	total: 2.17s	remaining: 1m 36s
# 22:	learn: 4077.5499846	test: 4061.4740387	best: 4061.4740387 (22)	total: 2.26s	remaining: 1m 36s
# 23:	learn: 4004.3496636	test: 3987.3819410	best: 3987.3819410 (23)	total: 2.35s	remaining: 1m 35s
# 24:	learn: 3934.1936874	test: 3916.7648797	best: 3916.7648797 (24)	total: 2.44s	remaining: 1m 35s
# 25:	learn: 3866.6464583	test: 3848.8877066	best: 3848.8877066 (25)	total: 2.55s	remaining: 1m 35s
# 26:	learn: 3799.3996693	test: 3781.4691579	best: 3781.4691579 (26)	total: 2.66s	remaining: 1m 35s
# 27:	learn: 3735.2189266	test: 3717.0516319	best: 3717.0516319 (27)	total: 2.76s	remaining: 1m 35s
# 28:	learn: 3674.9612289	test: 3656.3748861	best: 3656.3748861 (28)	total: 2.86s	remaining: 1m 35s
# 29:	learn: 3618.2666069	test: 3599.1835877	best: 3599.1835877 (29)	total: 2.93s	remaining: 1m 34s
# 30:	learn: 3562.3676076	test: 3542.7139858	best: 3542.7139858 (30)	total: 3.02s	remaining: 1m 34s
# 31:	learn: 3508.3720808	test: 3488.2153661	best: 3488.2153661 (31)	total: 3.12s	remaining: 1m 34s
# 32:	learn: 3456.8593873	test: 3436.2409172	best: 3436.2409172 (32)	total: 3.22s	remaining: 1m 34s
# 33:	learn: 3406.4058460	test: 3385.2456631	best: 3385.2456631 (33)	total: 3.31s	remaining: 1m 33s
# 34:	learn: 3358.0193229	test: 3336.4152008	best: 3336.4152008 (34)	total: 3.4s	remaining: 1m 33s
# 35:	learn: 3313.1692468	test: 3292.6473226	best: 3292.6473226 (35)	total: 3.47s	remaining: 1m 32s
# 36:	learn: 3268.7737567	test: 3247.9822911	best: 3247.9822911 (36)	total: 3.56s	remaining: 1m 32s
# 37:	learn: 3225.9941183	test: 3204.8116948	best: 3204.8116948 (37)	total: 3.66s	remaining: 1m 32s
# 38:	learn: 3184.4788502	test: 3163.0794556	best: 3163.0794556 (38)	total: 3.74s	remaining: 1m 32s
# 39:	learn: 3144.2736703	test: 3122.5639104	best: 3122.5639104 (39)	total: 3.82s	remaining: 1m 31s
# 40:	learn: 3105.4232404	test: 3083.2752768	best: 3083.2752768 (40)	total: 3.9s	remaining: 1m 31s
# 41:	learn: 3067.2421497	test: 3045.7119153	best: 3045.7119153 (41)	total: 3.96s	remaining: 1m 30s
# 42:	learn: 3030.4620117	test: 3009.5649322	best: 3009.5649322 (42)	total: 4.03s	remaining: 1m 29s
# 43:	learn: 2996.4978929	test: 2974.8442352	best: 2974.8442352 (43)	total: 4.11s	remaining: 1m 29s
# 44:	learn: 2963.6736263	test: 2942.3132152	best: 2942.3132152 (44)	total: 4.18s	remaining: 1m 28s
# 45:	learn: 2929.9844261	test: 2908.1729489	best: 2908.1729489 (45)	total: 4.29s	remaining: 1m 28s
# 46:	learn: 2899.9430341	test: 2877.7787057	best: 2877.7787057 (46)	total: 4.36s	remaining: 1m 28s
# 47:	learn: 2869.9838537	test: 2847.5713628	best: 2847.5713628 (47)	total: 4.45s	remaining: 1m 28s
# 48:	learn: 2842.2341346	test: 2820.4146229	best: 2820.4146229 (48)	total: 4.5s	remaining: 1m 27s
# 49:	learn: 2814.9895959	test: 2793.7979797	best: 2793.7979797 (49)	total: 4.58s	remaining: 1m 26s
# 50:	learn: 2789.1484150	test: 2768.4103078	best: 2768.4103078 (50)	total: 4.65s	remaining: 1m 26s
# 51:	learn: 2763.8297717	test: 2742.6916834	best: 2742.6916834 (51)	total: 4.72s	remaining: 1m 26s
# 52:	learn: 2738.3752270	test: 2717.2878147	best: 2717.2878147 (52)	total: 4.8s	remaining: 1m 25s
# 53:	learn: 2713.2501904	test: 2692.0520275	best: 2692.0520275 (53)	total: 4.89s	remaining: 1m 25s
# 54:	learn: 2689.3662671	test: 2667.8931123	best: 2667.8931123 (54)	total: 4.96s	remaining: 1m 25s
# 55:	learn: 2665.5710634	test: 2643.7176872	best: 2643.7176872 (55)	total: 5.04s	remaining: 1m 25s
# 56:	learn: 2643.4311954	test: 2621.4339793	best: 2621.4339793 (56)	total: 5.13s	remaining: 1m 24s
# 57:	learn: 2623.7509331	test: 2601.5230632	best: 2601.5230632 (57)	total: 5.21s	remaining: 1m 24s
# 58:	learn: 2604.0709939	test: 2581.7416702	best: 2581.7416702 (58)	total: 5.27s	remaining: 1m 24s
# 59:	learn: 2584.1168729	test: 2561.4777044	best: 2561.4777044 (59)	total: 5.32s	remaining: 1m 23s
# 60:	learn: 2563.5364428	test: 2540.8077719	best: 2540.8077719 (60)	total: 5.41s	remaining: 1m 23s
# 61:	learn: 2546.2665291	test: 2523.6219227	best: 2523.6219227 (61)	total: 5.47s	remaining: 1m 22s
# 62:	learn: 2527.3610934	test: 2504.4789087	best: 2504.4789087 (62)	total: 5.55s	remaining: 1m 22s
# 63:	learn: 2511.3926493	test: 2488.3241666	best: 2488.3241666 (63)	total: 5.61s	remaining: 1m 21s
# 64:	learn: 2495.6384154	test: 2472.6051379	best: 2472.6051379 (64)	total: 5.69s	remaining: 1m 21s
# 65:	learn: 2480.5677983	test: 2457.5714195	best: 2457.5714195 (65)	total: 5.76s	remaining: 1m 21s
# 66:	learn: 2464.0652679	test: 2440.9971347	best: 2440.9971347 (66)	total: 5.85s	remaining: 1m 21s
# 67:	learn: 2449.3169892	test: 2426.2957244	best: 2426.2957244 (67)	total: 5.93s	remaining: 1m 21s
# 68:	learn: 2434.4023409	test: 2411.2394983	best: 2411.2394983 (68)	total: 6.03s	remaining: 1m 21s
# 69:	learn: 2419.4470614	test: 2396.3403866	best: 2396.3403866 (69)	total: 6.11s	remaining: 1m 21s
# 70:	learn: 2405.2072921	test: 2382.0455467	best: 2382.0455467 (70)	total: 6.19s	remaining: 1m 20s
# 71:	learn: 2392.2262122	test: 2369.0608895	best: 2369.0608895 (71)	total: 6.27s	remaining: 1m 20s
# 72:	learn: 2380.1628496	test: 2357.2573271	best: 2357.2573271 (72)	total: 6.36s	remaining: 1m 20s
# 73:	learn: 2366.6008775	test: 2343.7629223	best: 2343.7629223 (73)	total: 6.46s	remaining: 1m 20s
# 74:	learn: 2354.3398225	test: 2331.5679973	best: 2331.5679973 (74)	total: 6.55s	remaining: 1m 20s
# 75:	learn: 2342.5580701	test: 2319.6300304	best: 2319.6300304 (75)	total: 6.61s	remaining: 1m 20s
# 76:	learn: 2330.5652895	test: 2307.4749622	best: 2307.4749622 (76)	total: 6.69s	remaining: 1m 20s
# 77:	learn: 2319.0342098	test: 2295.9434644	best: 2295.9434644 (77)	total: 6.77s	remaining: 1m 20s
# 78:	learn: 2309.0026976	test: 2285.8888828	best: 2285.8888828 (78)	total: 6.86s	remaining: 1m 19s
# 79:	learn: 2298.0874620	test: 2275.6567051	best: 2275.6567051 (79)	total: 6.95s	remaining: 1m 19s
# 80:	learn: 2287.6567700	test: 2265.0987422	best: 2265.0987422 (80)	total: 7.03s	remaining: 1m 19s
# 81:	learn: 2278.6147417	test: 2255.9769703	best: 2255.9769703 (81)	total: 7.09s	remaining: 1m 19s
# 82:	learn: 2269.2203416	test: 2246.3900668	best: 2246.3900668 (82)	total: 7.19s	remaining: 1m 19s
# 83:	learn: 2259.6653999	test: 2236.6875265	best: 2236.6875265 (83)	total: 7.26s	remaining: 1m 19s
# 84:	learn: 2251.5122241	test: 2228.4744034	best: 2228.4744034 (84)	total: 7.33s	remaining: 1m 18s
# 85:	learn: 2242.8752227	test: 2219.7889398	best: 2219.7889398 (85)	total: 7.42s	remaining: 1m 18s
# 86:	learn: 2234.7673259	test: 2211.7172734	best: 2211.7172734 (86)	total: 7.51s	remaining: 1m 18s
# 87:	learn: 2226.6820339	test: 2203.5384276	best: 2203.5384276 (87)	total: 7.59s	remaining: 1m 18s
# 88:	learn: 2219.0459840	test: 2196.0515278	best: 2196.0515278 (88)	total: 7.68s	remaining: 1m 18s
# 89:	learn: 2211.7169185	test: 2188.7795581	best: 2188.7795581 (89)	total: 7.75s	remaining: 1m 18s
# 90:	learn: 2203.3185910	test: 2180.3996380	best: 2180.3996380 (90)	total: 7.84s	remaining: 1m 18s
# 91:	learn: 2196.6494890	test: 2173.7604325	best: 2173.7604325 (91)	total: 7.92s	remaining: 1m 18s
# 92:	learn: 2190.5161613	test: 2167.6953648	best: 2167.6953648 (92)	total: 8s	remaining: 1m 18s
# 93:	learn: 2184.5146012	test: 2161.7103808	best: 2161.7103808 (93)	total: 8.09s	remaining: 1m 17s
# 94:	learn: 2178.0967473	test: 2155.1720546	best: 2155.1720546 (94)	total: 8.16s	remaining: 1m 17s
# 95:	learn: 2171.6804342	test: 2148.5871408	best: 2148.5871408 (95)	total: 8.24s	remaining: 1m 17s
# 96:	learn: 2165.7145124	test: 2142.4126790	best: 2142.4126790 (96)	total: 8.32s	remaining: 1m 17s
# 97:	learn: 2158.5660759	test: 2135.3050086	best: 2135.3050086 (97)	total: 8.39s	remaining: 1m 17s
# 98:	learn: 2151.8671798	test: 2128.4760062	best: 2128.4760062 (98)	total: 8.46s	remaining: 1m 17s
# 99:	learn: 2145.4483841	test: 2122.1498992	best: 2122.1498992 (99)	total: 8.53s	remaining: 1m 16s
# 100:	learn: 2139.9458471	test: 2116.7366600	best: 2116.7366600 (100)	total: 8.59s	remaining: 1m 16s
# 101:	learn: 2134.5908630	test: 2111.3815081	best: 2111.3815081 (101)	total: 8.66s	remaining: 1m 16s
# 102:	learn: 2129.3345232	test: 2106.2449435	best: 2106.2449435 (102)	total: 8.73s	remaining: 1m 16s
# 103:	learn: 2124.1980458	test: 2101.1624713	best: 2101.1624713 (103)	total: 8.79s	remaining: 1m 15s
# 104:	learn: 2119.3961629	test: 2096.5720249	best: 2096.5720249 (104)	total: 8.85s	remaining: 1m 15s
# 105:	learn: 2114.3347265	test: 2091.5608114	best: 2091.5608114 (105)	total: 8.92s	remaining: 1m 15s
# 106:	learn: 2110.2296922	test: 2087.5357573	best: 2087.5357573 (106)	total: 8.98s	remaining: 1m 14s
# 107:	learn: 2105.3230527	test: 2082.4018945	best: 2082.4018945 (107)	total: 9.04s	remaining: 1m 14s
# 108:	learn: 2101.4924220	test: 2078.5452399	best: 2078.5452399 (108)	total: 9.1s	remaining: 1m 14s
# 109:	learn: 2097.8378107	test: 2074.9268105	best: 2074.9268105 (109)	total: 9.17s	remaining: 1m 14s
# 110:	learn: 2094.3531930	test: 2071.5418710	best: 2071.5418710 (110)	total: 9.23s	remaining: 1m 13s
# 111:	learn: 2090.0166921	test: 2067.1123791	best: 2067.1123791 (111)	total: 9.31s	remaining: 1m 13s
# 112:	learn: 2086.1356043	test: 2063.2693297	best: 2063.2693297 (112)	total: 9.37s	remaining: 1m 13s
# 113:	learn: 2082.1273513	test: 2059.0640585	best: 2059.0640585 (113)	total: 9.43s	remaining: 1m 13s
# 114:	learn: 2078.4633523	test: 2055.2934991	best: 2055.2934991 (114)	total: 9.5s	remaining: 1m 13s
# 115:	learn: 2074.0380254	test: 2050.8430436	best: 2050.8430436 (115)	total: 9.58s	remaining: 1m 12s
# 116:	learn: 2069.6480812	test: 2046.5168875	best: 2046.5168875 (116)	total: 9.64s	remaining: 1m 12s
# 117:	learn: 2066.6384234	test: 2043.6050834	best: 2043.6050834 (117)	total: 9.71s	remaining: 1m 12s
# 118:	learn: 2063.1250418	test: 2039.9216604	best: 2039.9216604 (118)	total: 9.75s	remaining: 1m 12s
# 119:	learn: 2059.2956097	test: 2036.0661582	best: 2036.0661582 (119)	total: 9.83s	remaining: 1m 12s
# 120:	learn: 2056.5526852	test: 2033.2169315	best: 2033.2169315 (120)	total: 9.9s	remaining: 1m 11s
# 121:	learn: 2053.3024494	test: 2029.9297660	best: 2029.9297660 (121)	total: 9.95s	remaining: 1m 11s
# 122:	learn: 2049.8275077	test: 2026.4391268	best: 2026.4391268 (122)	total: 10s	remaining: 1m 11s
# 123:	learn: 2047.2614098	test: 2023.9630870	best: 2023.9630870 (123)	total: 10.1s	remaining: 1m 11s
# 124:	learn: 2044.1337084	test: 2020.8500809	best: 2020.8500809 (124)	total: 10.1s	remaining: 1m 10s
# 125:	learn: 2040.9790525	test: 2017.7091497	best: 2017.7091497 (125)	total: 10.2s	remaining: 1m 10s
# 126:	learn: 2038.5125853	test: 2015.2417156	best: 2015.2417156 (126)	total: 10.3s	remaining: 1m 10s
# 127:	learn: 2035.2967901	test: 2011.9165106	best: 2011.9165106 (127)	total: 10.3s	remaining: 1m 10s
# 128:	learn: 2032.3260200	test: 2008.9310923	best: 2008.9310923 (128)	total: 10.4s	remaining: 1m 10s
# 129:	learn: 2029.5332342	test: 2006.1787695	best: 2006.1787695 (129)	total: 10.5s	remaining: 1m 10s
# 130:	learn: 2026.5215381	test: 2003.1730082	best: 2003.1730082 (130)	total: 10.6s	remaining: 1m 10s
# 131:	learn: 2023.8630140	test: 2000.3671915	best: 2000.3671915 (131)	total: 10.6s	remaining: 1m 9s
# 132:	learn: 2021.0130247	test: 1997.4395512	best: 1997.4395512 (132)	total: 10.7s	remaining: 1m 9s
# 133:	learn: 2018.9791934	test: 1995.3972552	best: 1995.3972552 (133)	total: 10.8s	remaining: 1m 9s
# 134:	learn: 2015.8684891	test: 1992.2533533	best: 1992.2533533 (134)	total: 10.9s	remaining: 1m 9s
# 135:	learn: 2013.7266218	test: 1990.0971116	best: 1990.0971116 (135)	total: 10.9s	remaining: 1m 9s
# 136:	learn: 2012.0673640	test: 1988.6344335	best: 1988.6344335 (136)	total: 11s	remaining: 1m 9s
# 137:	learn: 2010.2417000	test: 1986.8657826	best: 1986.8657826 (137)	total: 11s	remaining: 1m 8s
# 138:	learn: 2007.4687146	test: 1984.0423760	best: 1984.0423760 (138)	total: 11.1s	remaining: 1m 8s
# 139:	learn: 2005.2308396	test: 1981.8448237	best: 1981.8448237 (139)	total: 11.2s	remaining: 1m 8s
# 140:	learn: 2003.0029192	test: 1979.6629909	best: 1979.6629909 (140)	total: 11.3s	remaining: 1m 8s
# 141:	learn: 2000.7043147	test: 1977.3830753	best: 1977.3830753 (141)	total: 11.4s	remaining: 1m 8s
# 142:	learn: 1998.8522386	test: 1975.5141791	best: 1975.5141791 (142)	total: 11.5s	remaining: 1m 8s
# 143:	learn: 1996.7941242	test: 1973.5527556	best: 1973.5527556 (143)	total: 11.5s	remaining: 1m 8s
# 144:	learn: 1994.3221239	test: 1971.0277794	best: 1971.0277794 (144)	total: 11.6s	remaining: 1m 8s
# 145:	learn: 1992.6571175	test: 1969.4172680	best: 1969.4172680 (145)	total: 11.7s	remaining: 1m 8s
# 146:	learn: 1991.3437214	test: 1968.1090750	best: 1968.1090750 (146)	total: 11.8s	remaining: 1m 8s
# 147:	learn: 1989.4105454	test: 1966.1986222	best: 1966.1986222 (147)	total: 11.8s	remaining: 1m 8s
# 148:	learn: 1988.0807713	test: 1964.8591845	best: 1964.8591845 (148)	total: 11.9s	remaining: 1m 7s
# 149:	learn: 1986.0913039	test: 1962.8298320	best: 1962.8298320 (149)	total: 12s	remaining: 1m 7s
# 150:	learn: 1984.4733825	test: 1961.1372054	best: 1961.1372054 (150)	total: 12s	remaining: 1m 7s
# 151:	learn: 1982.9903817	test: 1959.6790929	best: 1959.6790929 (151)	total: 12.1s	remaining: 1m 7s
# 152:	learn: 1980.5363649	test: 1957.3229167	best: 1957.3229167 (152)	total: 12.2s	remaining: 1m 7s
# 153:	learn: 1978.7015786	test: 1955.3633353	best: 1955.3633353 (153)	total: 12.3s	remaining: 1m 7s
# 154:	learn: 1976.9980651	test: 1953.4797307	best: 1953.4797307 (154)	total: 12.4s	remaining: 1m 7s
# 155:	learn: 1975.6349524	test: 1952.1972302	best: 1952.1972302 (155)	total: 12.4s	remaining: 1m 7s
# 156:	learn: 1973.9839838	test: 1950.3778309	best: 1950.3778309 (156)	total: 12.5s	remaining: 1m 7s
# 157:	learn: 1972.2466986	test: 1948.5424675	best: 1948.5424675 (157)	total: 12.6s	remaining: 1m 6s
# 158:	learn: 1970.5019913	test: 1946.6613591	best: 1946.6613591 (158)	total: 12.7s	remaining: 1m 6s
# 159:	learn: 1969.1626440	test: 1945.2773042	best: 1945.2773042 (159)	total: 12.7s	remaining: 1m 6s
# 160:	learn: 1967.7495020	test: 1943.8401869	best: 1943.8401869 (160)	total: 12.8s	remaining: 1m 6s
# 161:	learn: 1965.9733101	test: 1942.0922706	best: 1942.0922706 (161)	total: 12.9s	remaining: 1m 6s
# 162:	learn: 1963.9037576	test: 1940.1756381	best: 1940.1756381 (162)	total: 13s	remaining: 1m 6s
# 163:	learn: 1962.3822216	test: 1938.5416902	best: 1938.5416902 (163)	total: 13.1s	remaining: 1m 6s
# 164:	learn: 1960.6362931	test: 1936.8797315	best: 1936.8797315 (164)	total: 13.2s	remaining: 1m 6s
# 165:	learn: 1959.5520992	test: 1935.8314534	best: 1935.8314534 (165)	total: 13.2s	remaining: 1m 6s
# 166:	learn: 1958.1848994	test: 1934.3920925	best: 1934.3920925 (166)	total: 13.3s	remaining: 1m 6s
# 167:	learn: 1956.6798195	test: 1932.7638660	best: 1932.7638660 (167)	total: 13.4s	remaining: 1m 6s
# 168:	learn: 1955.4856198	test: 1931.5372171	best: 1931.5372171 (168)	total: 13.4s	remaining: 1m 6s
# 169:	learn: 1953.9779804	test: 1930.0583091	best: 1930.0583091 (169)	total: 13.5s	remaining: 1m 5s
# 170:	learn: 1952.6588680	test: 1928.6906846	best: 1928.6906846 (170)	total: 13.6s	remaining: 1m 5s
# 171:	learn: 1951.6749705	test: 1927.7041412	best: 1927.7041412 (171)	total: 13.6s	remaining: 1m 5s
# 172:	learn: 1950.4407942	test: 1926.4200970	best: 1926.4200970 (172)	total: 13.7s	remaining: 1m 5s
# 173:	learn: 1949.0115813	test: 1925.0540581	best: 1925.0540581 (173)	total: 13.8s	remaining: 1m 5s
# 174:	learn: 1947.3503854	test: 1923.4805986	best: 1923.4805986 (174)	total: 13.8s	remaining: 1m 5s
# 175:	learn: 1945.7469358	test: 1921.8911799	best: 1921.8911799 (175)	total: 13.9s	remaining: 1m 5s
# 176:	learn: 1944.4767577	test: 1920.6788607	best: 1920.6788607 (176)	total: 14s	remaining: 1m 5s
# 177:	learn: 1943.2774999	test: 1919.3806706	best: 1919.3806706 (177)	total: 14.1s	remaining: 1m 5s
# 178:	learn: 1942.0344470	test: 1918.0177818	best: 1918.0177818 (178)	total: 14.2s	remaining: 1m 5s
# 179:	learn: 1940.2261393	test: 1916.2563932	best: 1916.2563932 (179)	total: 14.3s	remaining: 1m 5s
# 180:	learn: 1939.0922916	test: 1915.0689643	best: 1915.0689643 (180)	total: 14.4s	remaining: 1m 4s
# 181:	learn: 1937.4455931	test: 1913.5441420	best: 1913.5441420 (181)	total: 14.5s	remaining: 1m 4s
# 182:	learn: 1936.3375165	test: 1912.3883691	best: 1912.3883691 (182)	total: 14.5s	remaining: 1m 4s
# 183:	learn: 1935.3396695	test: 1911.3389433	best: 1911.3389433 (183)	total: 14.6s	remaining: 1m 4s
# 184:	learn: 1934.3308605	test: 1910.3368121	best: 1910.3368121 (184)	total: 14.7s	remaining: 1m 4s
# 185:	learn: 1933.4280239	test: 1909.3848288	best: 1909.3848288 (185)	total: 14.7s	remaining: 1m 4s
# 186:	learn: 1932.5085974	test: 1908.5283807	best: 1908.5283807 (186)	total: 14.8s	remaining: 1m 4s
# 187:	learn: 1931.0409994	test: 1907.1981700	best: 1907.1981700 (187)	total: 14.9s	remaining: 1m 4s
# 188:	learn: 1929.7071098	test: 1905.8210419	best: 1905.8210419 (188)	total: 14.9s	remaining: 1m 4s
# 189:	learn: 1928.4084827	test: 1904.5641796	best: 1904.5641796 (189)	total: 15s	remaining: 1m 4s
# 190:	learn: 1927.2698629	test: 1903.3443649	best: 1903.3443649 (190)	total: 15.1s	remaining: 1m 3s
# 191:	learn: 1925.9483769	test: 1902.0422666	best: 1902.0422666 (191)	total: 15.2s	remaining: 1m 3s
# 192:	learn: 1925.0015183	test: 1901.0617487	best: 1901.0617487 (192)	total: 15.3s	remaining: 1m 3s
# 193:	learn: 1923.8524944	test: 1899.8872282	best: 1899.8872282 (193)	total: 15.4s	remaining: 1m 3s
# 194:	learn: 1922.6208598	test: 1898.6532500	best: 1898.6532500 (194)	total: 15.4s	remaining: 1m 3s
# 195:	learn: 1921.7103848	test: 1897.7789031	best: 1897.7789031 (195)	total: 15.5s	remaining: 1m 3s
# 196:	learn: 1920.9016907	test: 1896.9739349	best: 1896.9739349 (196)	total: 15.6s	remaining: 1m 3s
# 197:	learn: 1919.7580996	test: 1895.8561041	best: 1895.8561041 (197)	total: 15.7s	remaining: 1m 3s
# 198:	learn: 1918.5930382	test: 1894.6898694	best: 1894.6898694 (198)	total: 15.8s	remaining: 1m 3s
# 199:	learn: 1917.7664606	test: 1893.8360785	best: 1893.8360785 (199)	total: 15.8s	remaining: 1m 3s
# 200:	learn: 1916.7788462	test: 1892.7999715	best: 1892.7999715 (200)	total: 15.9s	remaining: 1m 3s
# 201:	learn: 1915.8897120	test: 1891.9117182	best: 1891.9117182 (201)	total: 16s	remaining: 1m 3s
# 202:	learn: 1914.9147607	test: 1891.0755265	best: 1891.0755265 (202)	total: 16.1s	remaining: 1m 3s
# 203:	learn: 1913.9859281	test: 1890.1679560	best: 1890.1679560 (203)	total: 16.2s	remaining: 1m 3s
# 204:	learn: 1913.2844048	test: 1889.4811547	best: 1889.4811547 (204)	total: 16.3s	remaining: 1m 3s
# 205:	learn: 1912.0417691	test: 1888.2374375	best: 1888.2374375 (205)	total: 16.4s	remaining: 1m 3s
# 206:	learn: 1911.1655364	test: 1887.3549381	best: 1887.3549381 (206)	total: 16.4s	remaining: 1m 3s
# 207:	learn: 1910.2578857	test: 1886.4996403	best: 1886.4996403 (207)	total: 16.5s	remaining: 1m 2s
# 208:	learn: 1908.8703154	test: 1885.1566069	best: 1885.1566069 (208)	total: 16.6s	remaining: 1m 2s
# 209:	learn: 1908.0491731	test: 1884.3816947	best: 1884.3816947 (209)	total: 16.7s	remaining: 1m 2s
# 210:	learn: 1906.7226081	test: 1883.0887353	best: 1883.0887353 (210)	total: 16.7s	remaining: 1m 2s
# 211:	learn: 1905.6242308	test: 1881.9286238	best: 1881.9286238 (211)	total: 16.8s	remaining: 1m 2s
# 212:	learn: 1905.0778055	test: 1881.2349562	best: 1881.2349562 (212)	total: 16.9s	remaining: 1m 2s
# 213:	learn: 1904.1343376	test: 1880.3144593	best: 1880.3144593 (213)	total: 17s	remaining: 1m 2s
# 214:	learn: 1903.2022534	test: 1879.4987465	best: 1879.4987465 (214)	total: 17s	remaining: 1m 2s
# 215:	learn: 1902.3955906	test: 1878.6337112	best: 1878.6337112 (215)	total: 17.1s	remaining: 1m 2s
# 216:	learn: 1901.5491215	test: 1877.6633123	best: 1877.6633123 (216)	total: 17.2s	remaining: 1m 2s
# 217:	learn: 1900.9631115	test: 1877.1703504	best: 1877.1703504 (217)	total: 17.3s	remaining: 1m 2s
# 218:	learn: 1900.0890091	test: 1876.3128778	best: 1876.3128778 (218)	total: 17.3s	remaining: 1m 1s
# 219:	learn: 1899.2174120	test: 1875.3944420	best: 1875.3944420 (219)	total: 17.4s	remaining: 1m 1s
# 220:	learn: 1898.2908103	test: 1874.4315049	best: 1874.4315049 (220)	total: 17.5s	remaining: 1m 1s
# 221:	learn: 1897.6804317	test: 1873.8687903	best: 1873.8687903 (221)	total: 17.6s	remaining: 1m 1s
# 222:	learn: 1896.9257900	test: 1873.0436087	best: 1873.0436087 (222)	total: 17.6s	remaining: 1m 1s
# 223:	learn: 1896.1377834	test: 1872.2405328	best: 1872.2405328 (223)	total: 17.7s	remaining: 1m 1s
# 224:	learn: 1895.1308960	test: 1871.3289433	best: 1871.3289433 (224)	total: 17.8s	remaining: 1m 1s
# 225:	learn: 1894.5121953	test: 1870.7047355	best: 1870.7047355 (225)	total: 17.9s	remaining: 1m 1s
# 226:	learn: 1893.5168052	test: 1869.6625938	best: 1869.6625938 (226)	total: 17.9s	remaining: 1m 1s
# 227:	learn: 1892.6218253	test: 1868.9009196	best: 1868.9009196 (227)	total: 18s	remaining: 1m
# 228:	learn: 1891.8391776	test: 1868.2140894	best: 1868.2140894 (228)	total: 18.1s	remaining: 1m
# 229:	learn: 1891.3062138	test: 1867.6310975	best: 1867.6310975 (229)	total: 18.2s	remaining: 1m
# 230:	learn: 1890.7757105	test: 1867.1896327	best: 1867.1896327 (230)	total: 18.3s	remaining: 1m
# 231:	learn: 1890.1508312	test: 1866.5032684	best: 1866.5032684 (231)	total: 18.4s	remaining: 1m
# 232:	learn: 1889.0499399	test: 1865.4171721	best: 1865.4171721 (232)	total: 18.4s	remaining: 1m
# 233:	learn: 1888.4527791	test: 1864.8829934	best: 1864.8829934 (233)	total: 18.5s	remaining: 1m
# 234:	learn: 1887.4851733	test: 1864.0271023	best: 1864.0271023 (234)	total: 18.6s	remaining: 1m
# 235:	learn: 1886.9707494	test: 1863.5277179	best: 1863.5277179 (235)	total: 18.7s	remaining: 1m
# 236:	learn: 1886.0301624	test: 1862.5841360	best: 1862.5841360 (236)	total: 18.7s	remaining: 1m
# 237:	learn: 1885.5126585	test: 1862.0791395	best: 1862.0791395 (237)	total: 18.8s	remaining: 1m
# 238:	learn: 1885.0489903	test: 1861.5335882	best: 1861.5335882 (238)	total: 18.9s	remaining: 1m
# 239:	learn: 1884.4109962	test: 1860.9400214	best: 1860.9400214 (239)	total: 19s	remaining: 1m
# 240:	learn: 1883.7132400	test: 1860.2188383	best: 1860.2188383 (240)	total: 19s	remaining: 59.9s
# 241:	learn: 1883.1607748	test: 1859.5988799	best: 1859.5988799 (241)	total: 19.1s	remaining: 59.9s
# 242:	learn: 1882.3381170	test: 1858.8156277	best: 1858.8156277 (242)	total: 19.2s	remaining: 59.7s
# 243:	learn: 1881.9443633	test: 1858.4005428	best: 1858.4005428 (243)	total: 19.2s	remaining: 59.6s
# 244:	learn: 1881.1327922	test: 1857.5539741	best: 1857.5539741 (244)	total: 19.3s	remaining: 59.6s
# 245:	learn: 1880.4930262	test: 1856.9204048	best: 1856.9204048 (245)	total: 19.4s	remaining: 59.4s
# 246:	learn: 1880.1216796	test: 1856.5534543	best: 1856.5534543 (246)	total: 19.5s	remaining: 59.3s
# 247:	learn: 1879.2983308	test: 1855.7842512	best: 1855.7842512 (247)	total: 19.6s	remaining: 59.3s
# 248:	learn: 1878.7955891	test: 1855.3586882	best: 1855.3586882 (248)	total: 19.6s	remaining: 59.2s
# 249:	learn: 1878.2709202	test: 1854.7978827	best: 1854.7978827 (249)	total: 19.7s	remaining: 59.1s
# 250:	learn: 1877.6357387	test: 1854.1520756	best: 1854.1520756 (250)	total: 19.8s	remaining: 59s
# 251:	learn: 1877.0034337	test: 1853.5774437	best: 1853.5774437 (251)	total: 19.9s	remaining: 59s
# 252:	learn: 1876.4340354	test: 1853.0662959	best: 1853.0662959 (252)	total: 19.9s	remaining: 58.9s
# 253:	learn: 1875.9955812	test: 1852.6018208	best: 1852.6018208 (253)	total: 20s	remaining: 58.8s
# 254:	learn: 1874.8677407	test: 1851.2945051	best: 1851.2945051 (254)	total: 20.1s	remaining: 58.6s
# 255:	learn: 1874.3150807	test: 1850.7005573	best: 1850.7005573 (255)	total: 20.2s	remaining: 58.6s
# 256:	learn: 1873.7107151	test: 1850.0845160	best: 1850.0845160 (256)	total: 20.2s	remaining: 58.5s
# 257:	learn: 1873.2894131	test: 1849.7242686	best: 1849.7242686 (257)	total: 20.3s	remaining: 58.4s
# 258:	learn: 1872.7764655	test: 1849.2849823	best: 1849.2849823 (258)	total: 20.4s	remaining: 58.4s
# 259:	learn: 1871.9359423	test: 1848.5732733	best: 1848.5732733 (259)	total: 20.5s	remaining: 58.3s
# 260:	learn: 1871.6221146	test: 1848.2822544	best: 1848.2822544 (260)	total: 20.6s	remaining: 58.3s
# 261:	learn: 1871.1366821	test: 1847.8634714	best: 1847.8634714 (261)	total: 20.7s	remaining: 58.2s
# 262:	learn: 1870.7166516	test: 1847.3975037	best: 1847.3975037 (262)	total: 20.7s	remaining: 58s
# 263:	learn: 1870.0799204	test: 1846.7550840	best: 1846.7550840 (263)	total: 20.8s	remaining: 58s
# 264:	learn: 1869.2820095	test: 1845.9544432	best: 1845.9544432 (264)	total: 20.9s	remaining: 57.9s
# 265:	learn: 1868.9536656	test: 1845.5886121	best: 1845.5886121 (265)	total: 20.9s	remaining: 57.8s
# 266:	learn: 1868.3046642	test: 1844.9948847	best: 1844.9948847 (266)	total: 21s	remaining: 57.7s
# 267:	learn: 1867.2546580	test: 1843.9696036	best: 1843.9696036 (267)	total: 21.1s	remaining: 57.7s
# 268:	learn: 1866.5601469	test: 1843.2844541	best: 1843.2844541 (268)	total: 21.2s	remaining: 57.7s
# 269:	learn: 1866.2784012	test: 1842.9923833	best: 1842.9923833 (269)	total: 21.3s	remaining: 57.5s
# 270:	learn: 1865.7342612	test: 1842.5015686	best: 1842.5015686 (270)	total: 21.4s	remaining: 57.5s
# 271:	learn: 1865.2221712	test: 1841.9281151	best: 1841.9281151 (271)	total: 21.4s	remaining: 57.4s
# 272:	learn: 1864.7528129	test: 1841.5187530	best: 1841.5187530 (272)	total: 21.5s	remaining: 57.4s
# 273:	learn: 1864.2997732	test: 1841.0618195	best: 1841.0618195 (273)	total: 21.6s	remaining: 57.3s
# 274:	learn: 1863.6074393	test: 1840.3588181	best: 1840.3588181 (274)	total: 21.7s	remaining: 57.1s
# 275:	learn: 1862.6615472	test: 1839.2287809	best: 1839.2287809 (275)	total: 21.7s	remaining: 57s
# 276:	learn: 1861.7978625	test: 1838.4552097	best: 1838.4552097 (276)	total: 21.8s	remaining: 57s
# 277:	learn: 1861.2520181	test: 1837.9758373	best: 1837.9758373 (277)	total: 21.9s	remaining: 56.9s
# 278:	learn: 1860.8563548	test: 1837.5932211	best: 1837.5932211 (278)	total: 22s	remaining: 56.8s
# 279:	learn: 1860.3720409	test: 1837.2027187	best: 1837.2027187 (279)	total: 22.1s	remaining: 56.7s
# 280:	learn: 1859.7746672	test: 1836.6840713	best: 1836.6840713 (280)	total: 22.1s	remaining: 56.6s
# 281:	learn: 1858.6800837	test: 1835.7574901	best: 1835.7574901 (281)	total: 22.2s	remaining: 56.6s
# 282:	learn: 1858.2926776	test: 1835.3432566	best: 1835.3432566 (282)	total: 22.3s	remaining: 56.5s
# 283:	learn: 1857.8712252	test: 1835.0269690	best: 1835.0269690 (283)	total: 22.4s	remaining: 56.5s
# 284:	learn: 1857.3411125	test: 1834.4361949	best: 1834.4361949 (284)	total: 22.5s	remaining: 56.4s
# 285:	learn: 1856.7233043	test: 1833.6849516	best: 1833.6849516 (285)	total: 22.5s	remaining: 56.2s
# 286:	learn: 1856.0890203	test: 1833.0091174	best: 1833.0091174 (286)	total: 22.6s	remaining: 56.1s
# 287:	learn: 1855.6073701	test: 1832.5156600	best: 1832.5156600 (287)	total: 22.7s	remaining: 56s
# 288:	learn: 1855.0110199	test: 1831.8889999	best: 1831.8889999 (288)	total: 22.7s	remaining: 55.9s
# 289:	learn: 1854.2271897	test: 1831.2237656	best: 1831.2237656 (289)	total: 22.8s	remaining: 55.8s
# 290:	learn: 1853.4531127	test: 1830.5726014	best: 1830.5726014 (290)	total: 22.9s	remaining: 55.8s
# 291:	learn: 1852.9852676	test: 1830.1735039	best: 1830.1735039 (291)	total: 23s	remaining: 55.7s
# 292:	learn: 1852.2591836	test: 1829.4465478	best: 1829.4465478 (292)	total: 23s	remaining: 55.6s
# 293:	learn: 1851.8782119	test: 1829.0666434	best: 1829.0666434 (293)	total: 23.1s	remaining: 55.5s
# 294:	learn: 1851.3076499	test: 1828.5626691	best: 1828.5626691 (294)	total: 23.2s	remaining: 55.4s
# 295:	learn: 1851.0906287	test: 1828.3630030	best: 1828.3630030 (295)	total: 23.3s	remaining: 55.4s
# 296:	learn: 1850.3597023	test: 1827.7582720	best: 1827.7582720 (296)	total: 23.4s	remaining: 55.3s
# 297:	learn: 1849.8886749	test: 1827.2974652	best: 1827.2974652 (297)	total: 23.4s	remaining: 55.2s
# 298:	learn: 1849.5316561	test: 1826.9258597	best: 1826.9258597 (298)	total: 23.5s	remaining: 55.1s
# 299:	learn: 1849.0789918	test: 1826.5212669	best: 1826.5212669 (299)	total: 23.6s	remaining: 55s
# 300:	learn: 1848.6313740	test: 1826.0601103	best: 1826.0601103 (300)	total: 23.6s	remaining: 54.9s
# 301:	learn: 1847.9176011	test: 1825.3586471	best: 1825.3586471 (301)	total: 23.7s	remaining: 54.9s
# 302:	learn: 1847.4030855	test: 1824.8858803	best: 1824.8858803 (302)	total: 23.8s	remaining: 54.8s
# 303:	learn: 1846.9766688	test: 1824.5202567	best: 1824.5202567 (303)	total: 23.9s	remaining: 54.7s
# 304:	learn: 1846.2357272	test: 1823.8036030	best: 1823.8036030 (304)	total: 24s	remaining: 54.6s
# 305:	learn: 1845.8530578	test: 1823.4057140	best: 1823.4057140 (305)	total: 24.1s	remaining: 54.6s
# 306:	learn: 1845.0718975	test: 1822.6522171	best: 1822.6522171 (306)	total: 24.1s	remaining: 54.5s
# 307:	learn: 1844.1310403	test: 1821.7755788	best: 1821.7755788 (307)	total: 24.2s	remaining: 54.4s
# 308:	learn: 1843.7355439	test: 1821.2878991	best: 1821.2878991 (308)	total: 24.3s	remaining: 54.3s
# 309:	learn: 1843.1546359	test: 1820.7826565	best: 1820.7826565 (309)	total: 24.4s	remaining: 54.2s
# 310:	learn: 1842.6939748	test: 1820.3298021	best: 1820.3298021 (310)	total: 24.4s	remaining: 54.1s
# 311:	learn: 1842.3623801	test: 1820.0229958	best: 1820.0229958 (311)	total: 24.5s	remaining: 54s
# 312:	learn: 1841.9996190	test: 1819.6332534	best: 1819.6332534 (312)	total: 24.6s	remaining: 53.9s
# 313:	learn: 1841.7132741	test: 1819.3967741	best: 1819.3967741 (313)	total: 24.6s	remaining: 53.8s
# 314:	learn: 1841.2071552	test: 1818.8861191	best: 1818.8861191 (314)	total: 24.7s	remaining: 53.7s
# 315:	learn: 1840.7482547	test: 1818.4026979	best: 1818.4026979 (315)	total: 24.7s	remaining: 53.6s
# 316:	learn: 1840.3725711	test: 1817.9903549	best: 1817.9903549 (316)	total: 24.8s	remaining: 53.5s
# 317:	learn: 1840.1298689	test: 1817.7398376	best: 1817.7398376 (317)	total: 24.9s	remaining: 53.4s
# 318:	learn: 1839.6963005	test: 1817.2790208	best: 1817.2790208 (318)	total: 25s	remaining: 53.3s
# 319:	learn: 1839.3255483	test: 1816.8865844	best: 1816.8865844 (319)	total: 25.1s	remaining: 53.3s
# 320:	learn: 1839.0177828	test: 1816.6374646	best: 1816.6374646 (320)	total: 25.2s	remaining: 53.2s
# 321:	learn: 1838.6584860	test: 1816.2028304	best: 1816.2028304 (321)	total: 25.2s	remaining: 53.1s
# 322:	learn: 1838.3120058	test: 1815.9402332	best: 1815.9402332 (322)	total: 25.3s	remaining: 53s
# 323:	learn: 1837.7795014	test: 1815.5209612	best: 1815.5209612 (323)	total: 25.4s	remaining: 52.9s
# 324:	learn: 1837.2444955	test: 1815.0627301	best: 1815.0627301 (324)	total: 25.4s	remaining: 52.8s
# 325:	learn: 1837.0151052	test: 1814.8144228	best: 1814.8144228 (325)	total: 25.5s	remaining: 52.7s
# 326:	learn: 1836.4520523	test: 1814.2886840	best: 1814.2886840 (326)	total: 25.6s	remaining: 52.7s
# 327:	learn: 1836.0542342	test: 1813.8808464	best: 1813.8808464 (327)	total: 25.7s	remaining: 52.6s
# 328:	learn: 1835.5250052	test: 1813.3705087	best: 1813.3705087 (328)	total: 25.7s	remaining: 52.5s
# 329:	learn: 1835.2691391	test: 1813.1071319	best: 1813.1071319 (329)	total: 25.8s	remaining: 52.4s
# 330:	learn: 1834.7165683	test: 1812.6036856	best: 1812.6036856 (330)	total: 25.9s	remaining: 52.3s
# 331:	learn: 1834.4366243	test: 1812.2878350	best: 1812.2878350 (331)	total: 26s	remaining: 52.2s
# 332:	learn: 1834.1154481	test: 1812.0330735	best: 1812.0330735 (332)	total: 26s	remaining: 52.1s
# 333:	learn: 1833.5368367	test: 1811.5667968	best: 1811.5667968 (333)	total: 26.1s	remaining: 52.1s
# 334:	learn: 1833.0883830	test: 1811.1312135	best: 1811.1312135 (334)	total: 26.2s	remaining: 52s
# 335:	learn: 1832.6301257	test: 1810.7262060	best: 1810.7262060 (335)	total: 26.3s	remaining: 52s
# 336:	learn: 1832.1647959	test: 1810.2072229	best: 1810.2072229 (336)	total: 26.4s	remaining: 51.9s
# 337:	learn: 1831.7320996	test: 1809.8438563	best: 1809.8438563 (337)	total: 26.4s	remaining: 51.8s
# 338:	learn: 1831.3149182	test: 1809.4507961	best: 1809.4507961 (338)	total: 26.5s	remaining: 51.8s
# 339:	learn: 1830.7653223	test: 1808.8674112	best: 1808.8674112 (339)	total: 26.6s	remaining: 51.7s
# 340:	learn: 1830.2970655	test: 1808.3428662	best: 1808.3428662 (340)	total: 26.7s	remaining: 51.6s
# 341:	learn: 1830.1059115	test: 1808.1592919	best: 1808.1592919 (341)	total: 26.8s	remaining: 51.5s
# 342:	learn: 1829.7089441	test: 1807.6852691	best: 1807.6852691 (342)	total: 26.8s	remaining: 51.4s
# 343:	learn: 1829.2970859	test: 1807.3076030	best: 1807.3076030 (343)	total: 26.9s	remaining: 51.3s
# 344:	learn: 1828.9002820	test: 1806.9387366	best: 1806.9387366 (344)	total: 27s	remaining: 51.2s
# 345:	learn: 1828.5031956	test: 1806.4927214	best: 1806.4927214 (345)	total: 27s	remaining: 51.1s
# 346:	learn: 1828.1517193	test: 1806.1458342	best: 1806.1458342 (346)	total: 27.1s	remaining: 51s
# 347:	learn: 1827.9216074	test: 1805.9290100	best: 1805.9290100 (347)	total: 27.2s	remaining: 50.9s
# 348:	learn: 1827.6572425	test: 1805.6469588	best: 1805.6469588 (348)	total: 27.3s	remaining: 50.9s
# 349:	learn: 1827.2125983	test: 1805.1468195	best: 1805.1468195 (349)	total: 27.3s	remaining: 50.8s
# 350:	learn: 1826.9047680	test: 1804.8358366	best: 1804.8358366 (350)	total: 27.4s	remaining: 50.7s
# 351:	learn: 1826.5864840	test: 1804.5085372	best: 1804.5085372 (351)	total: 27.5s	remaining: 50.6s
# 352:	learn: 1826.1953933	test: 1804.0671016	best: 1804.0671016 (352)	total: 27.5s	remaining: 50.4s
# 353:	learn: 1825.9098151	test: 1803.8004527	best: 1803.8004527 (353)	total: 27.6s	remaining: 50.4s
# 354:	learn: 1825.3686109	test: 1803.4054644	best: 1803.4054644 (354)	total: 27.7s	remaining: 50.3s
# 355:	learn: 1825.1096094	test: 1803.2139891	best: 1803.2139891 (355)	total: 27.8s	remaining: 50.2s
# 356:	learn: 1824.2546925	test: 1802.2627314	best: 1802.2627314 (356)	total: 27.8s	remaining: 50.1s
# 357:	learn: 1823.8911144	test: 1801.9773640	best: 1801.9773640 (357)	total: 27.9s	remaining: 50.1s
# 358:	learn: 1823.5909498	test: 1801.5507034	best: 1801.5507034 (358)	total: 28s	remaining: 49.9s
# 359:	learn: 1823.2905887	test: 1801.2918175	best: 1801.2918175 (359)	total: 28s	remaining: 49.9s
# 360:	learn: 1822.6779360	test: 1800.7820041	best: 1800.7820041 (360)	total: 28.1s	remaining: 49.8s
# 361:	learn: 1822.2895919	test: 1800.5168108	best: 1800.5168108 (361)	total: 28.2s	remaining: 49.7s
# 362:	learn: 1821.9097740	test: 1800.1112507	best: 1800.1112507 (362)	total: 28.3s	remaining: 49.6s
# 363:	learn: 1821.5086267	test: 1799.7448414	best: 1799.7448414 (363)	total: 28.4s	remaining: 49.5s
# 364:	learn: 1821.1599407	test: 1799.3759669	best: 1799.3759669 (364)	total: 28.4s	remaining: 49.5s
# 365:	learn: 1820.8764659	test: 1799.1121495	best: 1799.1121495 (365)	total: 28.5s	remaining: 49.4s
# 366:	learn: 1820.2487506	test: 1798.6790115	best: 1798.6790115 (366)	total: 28.6s	remaining: 49.3s
# 367:	learn: 1819.8269616	test: 1798.2294163	best: 1798.2294163 (367)	total: 28.6s	remaining: 49.2s
# 368:	learn: 1819.5653600	test: 1797.8928454	best: 1797.8928454 (368)	total: 28.7s	remaining: 49.1s
# 369:	learn: 1819.3072783	test: 1797.6444561	best: 1797.6444561 (369)	total: 28.8s	remaining: 49s
# 370:	learn: 1818.8400852	test: 1797.2109517	best: 1797.2109517 (370)	total: 28.9s	remaining: 48.9s
# 371:	learn: 1818.3389563	test: 1796.7603486	best: 1796.7603486 (371)	total: 28.9s	remaining: 48.9s
# 372:	learn: 1817.8680391	test: 1796.3195974	best: 1796.3195974 (372)	total: 29s	remaining: 48.8s
# 373:	learn: 1817.6124200	test: 1796.1005033	best: 1796.1005033 (373)	total: 29.1s	remaining: 48.7s
# 374:	learn: 1817.4069129	test: 1795.9070454	best: 1795.9070454 (374)	total: 29.2s	remaining: 48.6s
# 375:	learn: 1817.1388719	test: 1795.6640423	best: 1795.6640423 (375)	total: 29.2s	remaining: 48.5s
# 376:	learn: 1816.8096890	test: 1795.3856842	best: 1795.3856842 (376)	total: 29.3s	remaining: 48.5s
# 377:	learn: 1816.5508400	test: 1795.0555009	best: 1795.0555009 (377)	total: 29.4s	remaining: 48.4s
# 378:	learn: 1816.1237737	test: 1794.3616242	best: 1794.3616242 (378)	total: 29.5s	remaining: 48.3s
# 379:	learn: 1815.8605699	test: 1794.0409671	best: 1794.0409671 (379)	total: 29.5s	remaining: 48.2s
# 380:	learn: 1815.5054156	test: 1793.6853999	best: 1793.6853999 (380)	total: 29.6s	remaining: 48.1s
# 381:	learn: 1815.2008153	test: 1793.3419456	best: 1793.3419456 (381)	total: 29.7s	remaining: 48s
# 382:	learn: 1814.6782714	test: 1793.0866836	best: 1793.0866836 (382)	total: 29.7s	remaining: 47.9s
# 383:	learn: 1814.3025455	test: 1792.7243860	best: 1792.7243860 (383)	total: 29.8s	remaining: 47.9s
# 384:	learn: 1814.1688014	test: 1792.6119494	best: 1792.6119494 (384)	total: 29.9s	remaining: 47.8s
# 385:	learn: 1813.5849433	test: 1792.0051045	best: 1792.0051045 (385)	total: 30s	remaining: 47.7s
# 386:	learn: 1813.2618000	test: 1791.6731515	best: 1791.6731515 (386)	total: 30.1s	remaining: 47.6s
# 387:	learn: 1813.1042721	test: 1791.4776645	best: 1791.4776645 (387)	total: 30.1s	remaining: 47.5s
# 388:	learn: 1812.7224127	test: 1791.0545028	best: 1791.0545028 (388)	total: 30.2s	remaining: 47.4s
# 389:	learn: 1812.4644203	test: 1790.8049505	best: 1790.8049505 (389)	total: 30.3s	remaining: 47.4s
# 390:	learn: 1812.1772229	test: 1790.4972889	best: 1790.4972889 (390)	total: 30.4s	remaining: 47.3s
# 391:	learn: 1811.7773483	test: 1790.1554286	best: 1790.1554286 (391)	total: 30.4s	remaining: 47.2s
# 392:	learn: 1811.4468929	test: 1789.7684235	best: 1789.7684235 (392)	total: 30.5s	remaining: 47.1s
# 393:	learn: 1810.7745476	test: 1789.4400978	best: 1789.4400978 (393)	total: 30.6s	remaining: 47s
# 394:	learn: 1810.4534986	test: 1789.1450005	best: 1789.1450005 (394)	total: 30.6s	remaining: 46.9s
# 395:	learn: 1810.1042446	test: 1788.8820117	best: 1788.8820117 (395)	total: 30.7s	remaining: 46.9s
# 396:	learn: 1809.8807608	test: 1788.6892801	best: 1788.6892801 (396)	total: 30.8s	remaining: 46.8s
# 397:	learn: 1809.2501855	test: 1788.3797770	best: 1788.3797770 (397)	total: 30.9s	remaining: 46.7s
# 398:	learn: 1808.7953557	test: 1787.9418454	best: 1787.9418454 (398)	total: 31s	remaining: 46.7s
# 399:	learn: 1808.0763816	test: 1787.1274851	best: 1787.1274851 (399)	total: 31.1s	remaining: 46.6s
# 400:	learn: 1807.8508102	test: 1786.8516884	best: 1786.8516884 (400)	total: 31.1s	remaining: 46.5s
# 401:	learn: 1807.5266766	test: 1786.6059408	best: 1786.6059408 (401)	total: 31.2s	remaining: 46.4s
# 402:	learn: 1807.2268626	test: 1786.3735209	best: 1786.3735209 (402)	total: 31.3s	remaining: 46.4s
# 403:	learn: 1806.9336685	test: 1786.1167026	best: 1786.1167026 (403)	total: 31.4s	remaining: 46.3s
# 404:	learn: 1806.6945745	test: 1785.9386823	best: 1785.9386823 (404)	total: 31.5s	remaining: 46.2s
# 405:	learn: 1806.3695423	test: 1785.5902646	best: 1785.5902646 (405)	total: 31.6s	remaining: 46.2s
# 406:	learn: 1806.1367217	test: 1785.3897157	best: 1785.3897157 (406)	total: 31.6s	remaining: 46.1s
# 407:	learn: 1805.6931229	test: 1785.0304403	best: 1785.0304403 (407)	total: 31.7s	remaining: 46s
# 408:	learn: 1805.4067529	test: 1784.7483647	best: 1784.7483647 (408)	total: 31.8s	remaining: 46s
# 409:	learn: 1804.9977570	test: 1784.3212160	best: 1784.3212160 (409)	total: 31.9s	remaining: 45.9s
# 410:	learn: 1804.3650237	test: 1783.8039968	best: 1783.8039968 (410)	total: 31.9s	remaining: 45.8s
# 411:	learn: 1804.0264337	test: 1783.4740709	best: 1783.4740709 (411)	total: 32s	remaining: 45.7s
# 412:	learn: 1803.8254625	test: 1783.2692197	best: 1783.2692197 (412)	total: 32.1s	remaining: 45.6s
# 413:	learn: 1803.4996573	test: 1782.9855840	best: 1782.9855840 (413)	total: 32.2s	remaining: 45.5s
# 414:	learn: 1803.1132819	test: 1782.6777247	best: 1782.6777247 (414)	total: 32.2s	remaining: 45.4s
# 415:	learn: 1802.8428135	test: 1782.4226956	best: 1782.4226956 (415)	total: 32.3s	remaining: 45.3s
# 416:	learn: 1802.5236497	test: 1782.1885614	best: 1782.1885614 (416)	total: 32.4s	remaining: 45.2s
# 417:	learn: 1801.9464371	test: 1781.8201861	best: 1781.8201861 (417)	total: 32.4s	remaining: 45.2s
# 418:	learn: 1801.7573933	test: 1781.6419372	best: 1781.6419372 (418)	total: 32.5s	remaining: 45.1s
# 419:	learn: 1801.4546902	test: 1781.3748389	best: 1781.3748389 (419)	total: 32.6s	remaining: 45s
# 420:	learn: 1801.2037495	test: 1781.1624921	best: 1781.1624921 (420)	total: 32.7s	remaining: 45s
# 421:	learn: 1800.8408325	test: 1780.8846652	best: 1780.8846652 (421)	total: 32.8s	remaining: 44.9s
# 422:	learn: 1800.5348528	test: 1780.6141768	best: 1780.6141768 (422)	total: 32.9s	remaining: 44.8s
# 423:	learn: 1800.0201698	test: 1780.1740053	best: 1780.1740053 (423)	total: 32.9s	remaining: 44.7s
# 424:	learn: 1799.4348479	test: 1779.4831254	best: 1779.4831254 (424)	total: 33s	remaining: 44.7s
# 425:	learn: 1799.3089352	test: 1779.3960227	best: 1779.3960227 (425)	total: 33.1s	remaining: 44.6s
# 426:	learn: 1799.0178208	test: 1779.1119183	best: 1779.1119183 (426)	total: 33.2s	remaining: 44.5s
# 427:	learn: 1798.5998637	test: 1778.6813682	best: 1778.6813682 (427)	total: 33.2s	remaining: 44.4s
# 428:	learn: 1798.2178319	test: 1778.2153248	best: 1778.2153248 (428)	total: 33.3s	remaining: 44.3s
# 429:	learn: 1797.8645663	test: 1777.7394182	best: 1777.7394182 (429)	total: 33.4s	remaining: 44.2s
# 430:	learn: 1797.6664826	test: 1777.5572525	best: 1777.5572525 (430)	total: 33.5s	remaining: 44.2s
# 431:	learn: 1797.1632885	test: 1777.0459960	best: 1777.0459960 (431)	total: 33.5s	remaining: 44.1s
# 432:	learn: 1797.0446292	test: 1776.9740802	best: 1776.9740802 (432)	total: 33.6s	remaining: 44s
# 433:	learn: 1796.2878602	test: 1776.3348421	best: 1776.3348421 (433)	total: 33.7s	remaining: 43.9s
# 434:	learn: 1795.7970688	test: 1775.7914788	best: 1775.7914788 (434)	total: 33.8s	remaining: 43.9s
# 435:	learn: 1795.5914521	test: 1775.6193592	best: 1775.6193592 (435)	total: 33.8s	remaining: 43.8s
# 436:	learn: 1795.0457165	test: 1775.0266998	best: 1775.0266998 (436)	total: 33.9s	remaining: 43.7s
# 437:	learn: 1794.7054629	test: 1774.7700064	best: 1774.7700064 (437)	total: 34s	remaining: 43.7s
# 438:	learn: 1794.3059803	test: 1774.4085144	best: 1774.4085144 (438)	total: 34.2s	remaining: 43.6s
# 439:	learn: 1793.9233500	test: 1774.0282862	best: 1774.0282862 (439)	total: 34.3s	remaining: 43.6s
# 440:	learn: 1793.5937799	test: 1773.6908423	best: 1773.6908423 (440)	total: 34.3s	remaining: 43.5s
# 441:	learn: 1793.2337999	test: 1773.3378851	best: 1773.3378851 (441)	total: 34.4s	remaining: 43.5s
# 442:	learn: 1792.7437725	test: 1772.7370720	best: 1772.7370720 (442)	total: 34.5s	remaining: 43.4s
# 443:	learn: 1792.5418269	test: 1772.5832378	best: 1772.5832378 (443)	total: 34.6s	remaining: 43.3s
# 444:	learn: 1792.4255883	test: 1772.5221234	best: 1772.5221234 (444)	total: 34.7s	remaining: 43.2s
# 445:	learn: 1792.1246145	test: 1772.3067995	best: 1772.3067995 (445)	total: 34.8s	remaining: 43.2s
# 446:	learn: 1791.8710796	test: 1772.0758287	best: 1772.0758287 (446)	total: 34.9s	remaining: 43.1s
# 447:	learn: 1791.3550437	test: 1771.6429381	best: 1771.6429381 (447)	total: 35s	remaining: 43.1s
# 448:	learn: 1790.8721181	test: 1771.1132733	best: 1771.1132733 (448)	total: 35s	remaining: 43s
# 449:	learn: 1790.5728849	test: 1770.8579727	best: 1770.8579727 (449)	total: 35.1s	remaining: 42.9s
# 450:	learn: 1790.4226837	test: 1770.6322433	best: 1770.6322433 (450)	total: 35.2s	remaining: 42.9s
# 451:	learn: 1790.1981027	test: 1770.3884259	best: 1770.3884259 (451)	total: 35.3s	remaining: 42.8s
# 452:	learn: 1789.9504620	test: 1770.0995513	best: 1770.0995513 (452)	total: 35.3s	remaining: 42.7s
# 453:	learn: 1789.4793762	test: 1769.7049423	best: 1769.7049423 (453)	total: 35.4s	remaining: 42.6s
# 454:	learn: 1789.2633352	test: 1769.5399183	best: 1769.5399183 (454)	total: 35.5s	remaining: 42.5s
# 455:	learn: 1788.9623093	test: 1769.2318915	best: 1769.2318915 (455)	total: 35.6s	remaining: 42.5s
# 456:	learn: 1788.6509208	test: 1769.0161623	best: 1769.0161623 (456)	total: 35.7s	remaining: 42.4s
# 457:	learn: 1788.3149907	test: 1768.6832693	best: 1768.6832693 (457)	total: 35.8s	remaining: 42.3s
# 458:	learn: 1788.0848997	test: 1768.4877014	best: 1768.4877014 (458)	total: 35.9s	remaining: 42.3s
# 459:	learn: 1787.6231039	test: 1768.0449886	best: 1768.0449886 (459)	total: 36s	remaining: 42.2s
# 460:	learn: 1787.4193451	test: 1767.8993137	best: 1767.8993137 (460)	total: 36s	remaining: 42.1s
# 461:	learn: 1787.2638057	test: 1767.7760563	best: 1767.7760563 (461)	total: 36.1s	remaining: 42.1s
# 462:	learn: 1787.0326949	test: 1767.6011429	best: 1767.6011429 (462)	total: 36.2s	remaining: 42s
# 463:	learn: 1786.6371121	test: 1767.2688057	best: 1767.2688057 (463)	total: 36.4s	remaining: 42s
# 464:	learn: 1786.3988830	test: 1767.0594569	best: 1767.0594569 (464)	total: 36.5s	remaining: 42s
# 465:	learn: 1786.2583312	test: 1766.9591763	best: 1766.9591763 (465)	total: 36.6s	remaining: 41.9s
# 466:	learn: 1785.8171763	test: 1766.5927524	best: 1766.5927524 (466)	total: 36.6s	remaining: 41.8s
# 467:	learn: 1785.4616769	test: 1766.2904515	best: 1766.2904515 (467)	total: 36.7s	remaining: 41.7s
# 468:	learn: 1785.2501599	test: 1766.0004152	best: 1766.0004152 (468)	total: 36.8s	remaining: 41.6s
# 469:	learn: 1784.8522754	test: 1765.6744565	best: 1765.6744565 (469)	total: 36.9s	remaining: 41.6s
# 470:	learn: 1784.5057530	test: 1765.3311775	best: 1765.3311775 (470)	total: 37s	remaining: 41.5s
# 471:	learn: 1784.2450707	test: 1765.1536408	best: 1765.1536408 (471)	total: 37s	remaining: 41.4s
# 472:	learn: 1783.7729883	test: 1764.9259192	best: 1764.9259192 (472)	total: 37.1s	remaining: 41.4s
# 473:	learn: 1783.3674274	test: 1764.6296628	best: 1764.6296628 (473)	total: 37.2s	remaining: 41.3s
# 474:	learn: 1783.1842466	test: 1764.4956493	best: 1764.4956493 (474)	total: 37.3s	remaining: 41.2s
# 475:	learn: 1783.0721492	test: 1764.3969858	best: 1764.3969858 (475)	total: 37.4s	remaining: 41.2s
# 476:	learn: 1782.7723646	test: 1764.1011507	best: 1764.1011507 (476)	total: 37.5s	remaining: 41.1s
# 477:	learn: 1782.4903445	test: 1763.8311582	best: 1763.8311582 (477)	total: 37.6s	remaining: 41s
# 478:	learn: 1782.3329972	test: 1763.6814478	best: 1763.6814478 (478)	total: 37.6s	remaining: 41s
# 479:	learn: 1782.0824057	test: 1763.4345046	best: 1763.4345046 (479)	total: 37.7s	remaining: 40.9s
# 480:	learn: 1781.8935455	test: 1763.2446164	best: 1763.2446164 (480)	total: 37.8s	remaining: 40.8s
# 481:	learn: 1781.6648221	test: 1763.0323365	best: 1763.0323365 (481)	total: 37.9s	remaining: 40.7s
# 482:	learn: 1781.4570670	test: 1762.9227251	best: 1762.9227251 (482)	total: 38s	remaining: 40.6s
# 483:	learn: 1781.1608140	test: 1762.6562362	best: 1762.6562362 (483)	total: 38s	remaining: 40.5s
# 484:	learn: 1781.0407849	test: 1762.5849971	best: 1762.5849971 (484)	total: 38.1s	remaining: 40.5s
# 485:	learn: 1780.5524600	test: 1762.3174929	best: 1762.3174929 (485)	total: 38.2s	remaining: 40.4s
# ...
# 840:	learn: 1227.2678614	test: 1532.1657287	best: 1532.1657287 (840)	total: 3m 38s	remaining: 41.3s
# 841:	learn: 1226.5692528	test: 1532.1550460	best: 1532.1550460 (841)	total: 3m 38s	remaining: 41s
# 842:	learn: 1226.4746384	test: 1532.1670232	best: 1532.1550460 (841)	total: 3m 39s	remaining: 40.8s
# 843:	learn: 1226.2378541	test: 1532.1988902	best: 1532.1550460 (841)	total: 3m 39s	remaining: 40.5s
# 844:	learn: 1225.9772018	test: 1532.1582406	best: 1532.1550460 (841)	total: 3m 39s	remaining: 40.3s
# 845:	learn: 1225.7505871	test: 1532.1609893	best: 1532.1550460 (841)	total: 3m 39s	remaining: 40s
# 846:	learn: 1225.5722696	test: 1532.0949063	best: 1532.0949063 (846)	total: 3m 40s	remaining: 39.8s
# 847:	learn: 1225.3615029	test: 1532.0778055	best: 1532.0778055 (847)	total: 3m 40s	remaining: 39.5s
# 848:	learn: 1225.2335645	test: 1532.1312913	best: 1532.0778055 (847)	total: 3m 40s	remaining: 39.2s
# 849:	learn: 1225.0590989	test: 1532.0770366	best: 1532.0770366 (849)	total: 3m 40s	remaining: 39s
# 850:	learn: 1224.8520997	test: 1532.0331116	best: 1532.0331116 (850)	total: 3m 41s	remaining: 38.7s
# 851:	learn: 1224.5705147	test: 1532.0389347	best: 1532.0331116 (850)	total: 3m 41s	remaining: 38.5s
# 852:	learn: 1224.5282623	test: 1532.0465983	best: 1532.0331116 (850)	total: 3m 41s	remaining: 38.2s
# 853:	learn: 1223.9206118	test: 1531.9937239	best: 1531.9937239 (853)	total: 3m 41s	remaining: 37.9s
# 854:	learn: 1223.6876388	test: 1531.9705255	best: 1531.9705255 (854)	total: 3m 42s	remaining: 37.7s
# 855:	learn: 1223.5263154	test: 1531.9592893	best: 1531.9592893 (855)	total: 3m 42s	remaining: 37.4s
# 856:	learn: 1223.2518754	test: 1532.0344055	best: 1531.9592893 (855)	total: 3m 42s	remaining: 37.2s
# 857:	learn: 1222.9027765	test: 1532.0316738	best: 1531.9592893 (855)	total: 3m 42s	remaining: 36.9s
# 858:	learn: 1222.6825840	test: 1531.9961076	best: 1531.9592893 (855)	total: 3m 43s	remaining: 36.6s
# 859:	learn: 1222.3369665	test: 1531.9915573	best: 1531.9592893 (855)	total: 3m 43s	remaining: 36.4s
# 860:	learn: 1222.2348960	test: 1531.9988329	best: 1531.9592893 (855)	total: 3m 43s	remaining: 36.1s
# 861:	learn: 1222.2076799	test: 1532.0109660	best: 1531.9592893 (855)	total: 3m 44s	remaining: 35.9s
# 862:	learn: 1221.9574232	test: 1531.9851458	best: 1531.9592893 (855)	total: 3m 44s	remaining: 35.6s
# 863:	learn: 1221.5142104	test: 1531.8779009	best: 1531.8779009 (863)	total: 3m 44s	remaining: 35.3s
# 864:	learn: 1221.5045260	test: 1531.8780491	best: 1531.8779009 (863)	total: 3m 44s	remaining: 35.1s
# 865:	learn: 1221.3346887	test: 1531.8618584	best: 1531.8618584 (865)	total: 3m 44s	remaining: 34.8s
# 866:	learn: 1221.2496907	test: 1531.8762154	best: 1531.8618584 (865)	total: 3m 45s	remaining: 34.5s
# 867:	learn: 1220.9953121	test: 1531.8416162	best: 1531.8416162 (867)	total: 3m 45s	remaining: 34.3s
# 868:	learn: 1220.6738460	test: 1531.8004583	best: 1531.8004583 (868)	total: 3m 45s	remaining: 34s
# 869:	learn: 1220.4319804	test: 1531.8240783	best: 1531.8004583 (868)	total: 3m 46s	remaining: 33.8s
# 870:	learn: 1219.8425439	test: 1531.8436704	best: 1531.8004583 (868)	total: 3m 46s	remaining: 33.5s
# 871:	learn: 1219.5315660	test: 1531.8947658	best: 1531.8004583 (868)	total: 3m 46s	remaining: 33.3s
# 872:	learn: 1219.3167111	test: 1531.8357210	best: 1531.8004583 (868)	total: 3m 46s	remaining: 33s
# 873:	learn: 1219.0382763	test: 1531.8100984	best: 1531.8004583 (868)	total: 3m 47s	remaining: 32.7s
# 874:	learn: 1218.8379615	test: 1531.8756588	best: 1531.8004583 (868)	total: 3m 47s	remaining: 32.5s
# 875:	learn: 1218.5260961	test: 1531.9643756	best: 1531.8004583 (868)	total: 3m 47s	remaining: 32.2s
# 876:	learn: 1218.1929716	test: 1531.8258984	best: 1531.8004583 (868)	total: 3m 47s	remaining: 32s
# 877:	learn: 1218.0755219	test: 1531.7933312	best: 1531.7933312 (877)	total: 3m 48s	remaining: 31.7s
# 878:	learn: 1218.0081723	test: 1531.7823486	best: 1531.7823486 (878)	total: 3m 48s	remaining: 31.4s
# 879:	learn: 1217.8420812	test: 1531.8022662	best: 1531.7823486 (878)	total: 3m 48s	remaining: 31.2s
# 880:	learn: 1217.6917040	test: 1531.8063599	best: 1531.7823486 (878)	total: 3m 48s	remaining: 30.9s
# 881:	learn: 1217.4876034	test: 1531.6862324	best: 1531.6862324 (881)	total: 3m 49s	remaining: 30.7s
# 882:	learn: 1217.3594449	test: 1531.6522426	best: 1531.6522426 (882)	total: 3m 49s	remaining: 30.4s
# 883:	learn: 1217.0323471	test: 1531.5786890	best: 1531.5786890 (883)	total: 3m 49s	remaining: 30.1s
# 884:	learn: 1216.7478807	test: 1531.5715731	best: 1531.5715731 (884)	total: 3m 49s	remaining: 29.9s
# 885:	learn: 1216.5314788	test: 1531.5628511	best: 1531.5628511 (885)	total: 3m 50s	remaining: 29.6s
# 886:	learn: 1216.1752350	test: 1531.5264804	best: 1531.5264804 (886)	total: 3m 50s	remaining: 29.3s
# 887:	learn: 1215.9167142	test: 1531.5299882	best: 1531.5264804 (886)	total: 3m 50s	remaining: 29.1s
# 888:	learn: 1215.5212166	test: 1531.5038255	best: 1531.5038255 (888)	total: 3m 50s	remaining: 28.8s
# 889:	learn: 1215.3681555	test: 1531.5007442	best: 1531.5007442 (889)	total: 3m 50s	remaining: 28.5s
# 890:	learn: 1215.2178514	test: 1531.4542577	best: 1531.4542577 (890)	total: 3m 51s	remaining: 28.3s
# 891:	learn: 1215.1877804	test: 1531.4595153	best: 1531.4542577 (890)	total: 3m 51s	remaining: 28s
# 892:	learn: 1214.9585845	test: 1531.4974682	best: 1531.4542577 (890)	total: 3m 51s	remaining: 27.8s
# 893:	learn: 1214.9214480	test: 1531.5195342	best: 1531.4542577 (890)	total: 3m 52s	remaining: 27.5s
# 894:	learn: 1214.5108021	test: 1531.5545883	best: 1531.4542577 (890)	total: 3m 52s	remaining: 27.3s
# 895:	learn: 1214.1866388	test: 1531.4962403	best: 1531.4542577 (890)	total: 3m 52s	remaining: 27s
# 896:	learn: 1214.0401736	test: 1531.4874673	best: 1531.4542577 (890)	total: 3m 52s	remaining: 26.7s
# 897:	learn: 1213.7497792	test: 1531.3747605	best: 1531.3747605 (897)	total: 3m 53s	remaining: 26.5s
# 898:	learn: 1213.3932445	test: 1531.4202953	best: 1531.3747605 (897)	total: 3m 53s	remaining: 26.2s
# 899:	learn: 1213.1500002	test: 1531.4301759	best: 1531.3747605 (897)	total: 3m 53s	remaining: 26s
# 900:	learn: 1213.0135890	test: 1531.4400764	best: 1531.3747605 (897)	total: 3m 54s	remaining: 25.7s
# 901:	learn: 1212.4336491	test: 1531.3354830	best: 1531.3354830 (901)	total: 3m 54s	remaining: 25.5s
# 902:	learn: 1212.3294005	test: 1531.3205691	best: 1531.3205691 (902)	total: 3m 54s	remaining: 25.2s
# 903:	learn: 1212.1815890	test: 1531.2801098	best: 1531.2801098 (903)	total: 3m 54s	remaining: 24.9s
# 904:	learn: 1212.1481926	test: 1531.2689380	best: 1531.2689380 (904)	total: 3m 55s	remaining: 24.7s
# 905:	learn: 1211.6718854	test: 1531.1244482	best: 1531.1244482 (905)	total: 3m 55s	remaining: 24.4s
# 906:	learn: 1211.4792337	test: 1531.1441428	best: 1531.1244482 (905)	total: 3m 55s	remaining: 24.2s
# 907:	learn: 1211.1990563	test: 1531.1194056	best: 1531.1194056 (907)	total: 3m 55s	remaining: 23.9s
# 908:	learn: 1210.9732526	test: 1531.1327680	best: 1531.1194056 (907)	total: 3m 56s	remaining: 23.6s
# 909:	learn: 1210.6863694	test: 1530.9728574	best: 1530.9728574 (909)	total: 3m 56s	remaining: 23.4s
# 910:	learn: 1210.4647198	test: 1530.9616482	best: 1530.9616482 (910)	total: 3m 56s	remaining: 23.1s
# 911:	learn: 1210.3638977	test: 1530.9882714	best: 1530.9616482 (910)	total: 3m 57s	remaining: 22.9s
# 912:	learn: 1210.2668465	test: 1530.9704827	best: 1530.9616482 (910)	total: 3m 57s	remaining: 22.6s
# 913:	learn: 1209.8119287	test: 1530.9111642	best: 1530.9111642 (913)	total: 3m 57s	remaining: 22.4s
# 914:	learn: 1209.7802267	test: 1530.8976189	best: 1530.8976189 (914)	total: 3m 57s	remaining: 22.1s
# 915:	learn: 1209.6538126	test: 1530.8093205	best: 1530.8093205 (915)	total: 3m 58s	remaining: 21.8s
# 916:	learn: 1209.3374293	test: 1530.8085798	best: 1530.8085798 (916)	total: 3m 58s	remaining: 21.6s
# 917:	learn: 1208.8787710	test: 1530.8909603	best: 1530.8085798 (916)	total: 3m 58s	remaining: 21.3s
# 918:	learn: 1208.8655796	test: 1530.9014798	best: 1530.8085798 (916)	total: 3m 59s	remaining: 21.1s
# 919:	learn: 1208.7343048	test: 1530.9434236	best: 1530.8085798 (916)	total: 3m 59s	remaining: 20.8s
# 920:	learn: 1208.6674788	test: 1530.9350204	best: 1530.8085798 (916)	total: 3m 59s	remaining: 20.5s
# 921:	learn: 1208.6511809	test: 1530.9256652	best: 1530.8085798 (916)	total: 3m 59s	remaining: 20.3s
# 922:	learn: 1208.4155123	test: 1530.9121189	best: 1530.8085798 (916)	total: 4m	remaining: 20s
# 923:	learn: 1208.0636327	test: 1530.8599694	best: 1530.8085798 (916)	total: 4m	remaining: 19.8s
# 924:	learn: 1207.8549036	test: 1530.7987174	best: 1530.7987174 (924)	total: 4m	remaining: 19.5s
# 925:	learn: 1207.6642311	test: 1530.8352250	best: 1530.7987174 (924)	total: 4m	remaining: 19.2s
# 926:	learn: 1207.4771844	test: 1530.8233669	best: 1530.7987174 (924)	total: 4m 1s	remaining: 19s
# 927:	learn: 1207.2566239	test: 1530.8094312	best: 1530.7987174 (924)	total: 4m 1s	remaining: 18.7s
# 928:	learn: 1207.0583344	test: 1530.7968250	best: 1530.7968250 (928)	total: 4m 1s	remaining: 18.5s
# 929:	learn: 1206.9833316	test: 1530.7823510	best: 1530.7823510 (929)	total: 4m 1s	remaining: 18.2s
# 930:	learn: 1206.7292135	test: 1530.6656440	best: 1530.6656440 (930)	total: 4m 2s	remaining: 17.9s
# 931:	learn: 1206.6187974	test: 1530.6628426	best: 1530.6628426 (931)	total: 4m 2s	remaining: 17.7s
# 932:	learn: 1206.3409687	test: 1530.6623739	best: 1530.6623739 (932)	total: 4m 2s	remaining: 17.4s
# 933:	learn: 1206.1035282	test: 1530.7109389	best: 1530.6623739 (932)	total: 4m 2s	remaining: 17.2s
# 934:	learn: 1205.8976357	test: 1530.6810826	best: 1530.6623739 (932)	total: 4m 3s	remaining: 16.9s
# 935:	learn: 1205.6401035	test: 1530.5095068	best: 1530.5095068 (935)	total: 4m 3s	remaining: 16.6s
# 936:	learn: 1205.3911760	test: 1530.4401643	best: 1530.4401643 (936)	total: 4m 3s	remaining: 16.4s
# 937:	learn: 1205.1477943	test: 1530.4215628	best: 1530.4215628 (937)	total: 4m 3s	remaining: 16.1s
# 938:	learn: 1204.9200574	test: 1530.4569103	best: 1530.4215628 (937)	total: 4m 4s	remaining: 15.9s
# 939:	learn: 1204.8476405	test: 1530.4976841	best: 1530.4215628 (937)	total: 4m 4s	remaining: 15.6s
# 940:	learn: 1204.7192912	test: 1530.4212985	best: 1530.4212985 (940)	total: 4m 4s	remaining: 15.3s
# 941:	learn: 1204.4881073	test: 1530.4093657	best: 1530.4093657 (941)	total: 4m 4s	remaining: 15.1s
# 942:	learn: 1204.2539002	test: 1530.3586760	best: 1530.3586760 (942)	total: 4m 5s	remaining: 14.8s
# 943:	learn: 1204.0552288	test: 1530.2914127	best: 1530.2914127 (943)	total: 4m 5s	remaining: 14.6s
# 944:	learn: 1203.8993156	test: 1530.2779920	best: 1530.2779920 (944)	total: 4m 5s	remaining: 14.3s
# 945:	learn: 1203.6820089	test: 1530.2019294	best: 1530.2019294 (945)	total: 4m 5s	remaining: 14s
# 946:	learn: 1203.3571657	test: 1530.1029312	best: 1530.1029312 (946)	total: 4m 6s	remaining: 13.8s
# 947:	learn: 1203.2907869	test: 1530.1300060	best: 1530.1029312 (946)	total: 4m 6s	remaining: 13.5s
# 948:	learn: 1203.2474198	test: 1530.1263889	best: 1530.1029312 (946)	total: 4m 6s	remaining: 13.3s
# 949:	learn: 1203.0659845	test: 1530.1125591	best: 1530.1029312 (946)	total: 4m 6s	remaining: 13s
# 950:	learn: 1202.9657399	test: 1530.0738772	best: 1530.0738772 (950)	total: 4m 7s	remaining: 12.7s
# 951:	learn: 1202.6588600	test: 1530.0650892	best: 1530.0650892 (951)	total: 4m 7s	remaining: 12.5s
# 952:	learn: 1202.5396445	test: 1530.0235049	best: 1530.0235049 (952)	total: 4m 7s	remaining: 12.2s
# 953:	learn: 1202.1253087	test: 1530.1633049	best: 1530.0235049 (952)	total: 4m 7s	remaining: 12s
# 954:	learn: 1201.9292514	test: 1530.1599734	best: 1530.0235049 (952)	total: 4m 8s	remaining: 11.7s
# 955:	learn: 1201.9072799	test: 1530.1574028	best: 1530.0235049 (952)	total: 4m 8s	remaining: 11.4s
# 956:	learn: 1201.8136745	test: 1530.1762558	best: 1530.0235049 (952)	total: 4m 8s	remaining: 11.2s
# 957:	learn: 1201.7287253	test: 1530.2133471	best: 1530.0235049 (952)	total: 4m 9s	remaining: 10.9s
# 958:	learn: 1201.5072863	test: 1530.2351356	best: 1530.0235049 (952)	total: 4m 9s	remaining: 10.7s
# 959:	learn: 1201.2953039	test: 1530.2809615	best: 1530.0235049 (952)	total: 4m 9s	remaining: 10.4s
# 960:	learn: 1201.1836289	test: 1530.2477596	best: 1530.0235049 (952)	total: 4m 9s	remaining: 10.1s
# 961:	learn: 1200.9247057	test: 1530.2384876	best: 1530.0235049 (952)	total: 4m 10s	remaining: 9.88s
# 962:	learn: 1200.6809063	test: 1530.1906426	best: 1530.0235049 (952)	total: 4m 10s	remaining: 9.63s
# 963:	learn: 1200.5349001	test: 1530.1594260	best: 1530.0235049 (952)	total: 4m 10s	remaining: 9.37s
# 964:	learn: 1200.3473462	test: 1530.1172778	best: 1530.0235049 (952)	total: 4m 10s	remaining: 9.1s
# 965:	learn: 1200.2933247	test: 1530.1117849	best: 1530.0235049 (952)	total: 4m 11s	remaining: 8.84s
# 966:	learn: 1200.2259225	test: 1530.1386633	best: 1530.0235049 (952)	total: 4m 11s	remaining: 8.58s
# 967:	learn: 1199.7196496	test: 1530.2477580	best: 1530.0235049 (952)	total: 4m 11s	remaining: 8.32s
# 968:	learn: 1199.5872735	test: 1530.2856952	best: 1530.0235049 (952)	total: 4m 12s	remaining: 8.06s
# 969:	learn: 1199.4337205	test: 1530.3060995	best: 1530.0235049 (952)	total: 4m 12s	remaining: 7.8s
# 970:	learn: 1199.2438303	test: 1530.3308110	best: 1530.0235049 (952)	total: 4m 12s	remaining: 7.54s
# 971:	learn: 1198.9572407	test: 1530.2866164	best: 1530.0235049 (952)	total: 4m 12s	remaining: 7.28s
# 972:	learn: 1198.6462945	test: 1530.1760921	best: 1530.0235049 (952)	total: 4m 13s	remaining: 7.02s
# 973:	learn: 1198.4033717	test: 1530.1921276	best: 1530.0235049 (952)	total: 4m 13s	remaining: 6.76s
# 974:	learn: 1198.2897465	test: 1530.2680617	best: 1530.0235049 (952)	total: 4m 13s	remaining: 6.5s
# 975:	learn: 1198.1926571	test: 1530.2786517	best: 1530.0235049 (952)	total: 4m 13s	remaining: 6.25s
# 976:	learn: 1198.0171601	test: 1530.2024647	best: 1530.0235049 (952)	total: 4m 14s	remaining: 5.99s
# 977:	learn: 1197.8630394	test: 1530.1279790	best: 1530.0235049 (952)	total: 4m 14s	remaining: 5.73s
# 978:	learn: 1197.6733170	test: 1530.1547621	best: 1530.0235049 (952)	total: 4m 14s	remaining: 5.47s
# 979:	learn: 1197.5449511	test: 1530.1934210	best: 1530.0235049 (952)	total: 4m 15s	remaining: 5.21s
# 980:	learn: 1197.4637009	test: 1530.1911717	best: 1530.0235049 (952)	total: 4m 15s	remaining: 4.95s
# 981:	learn: 1197.4143827	test: 1530.1732853	best: 1530.0235049 (952)	total: 4m 15s	remaining: 4.69s
# 982:	learn: 1197.3940925	test: 1530.1691168	best: 1530.0235049 (952)	total: 4m 15s	remaining: 4.43s
# 983:	learn: 1197.2506089	test: 1530.2173793	best: 1530.0235049 (952)	total: 4m 16s	remaining: 4.17s
# 984:	learn: 1197.0039536	test: 1530.1898474	best: 1530.0235049 (952)	total: 4m 16s	remaining: 3.91s
# 985:	learn: 1196.9177773	test: 1530.1782620	best: 1530.0235049 (952)	total: 4m 16s	remaining: 3.65s
# 986:	learn: 1196.7560832	test: 1530.1647440	best: 1530.0235049 (952)	total: 4m 17s	remaining: 3.38s
# 987:	learn: 1196.4984742	test: 1530.1299791	best: 1530.0235049 (952)	total: 4m 17s	remaining: 3.13s
# 988:	learn: 1196.3742403	test: 1530.1225492	best: 1530.0235049 (952)	total: 4m 17s	remaining: 2.86s
# 989:	learn: 1196.1700921	test: 1530.1990751	best: 1530.0235049 (952)	total: 4m 17s	remaining: 2.6s
# 990:	learn: 1195.9839647	test: 1530.1972822	best: 1530.0235049 (952)	total: 4m 18s	remaining: 2.34s
# 991:	learn: 1195.7885018	test: 1530.2281027	best: 1530.0235049 (952)	total: 4m 18s	remaining: 2.08s
# 992:	learn: 1195.6661614	test: 1530.2604888	best: 1530.0235049 (952)	total: 4m 18s	remaining: 1.82s
# 993:	learn: 1195.5508541	test: 1530.2054018	best: 1530.0235049 (952)	total: 4m 18s	remaining: 1.56s
# 994:	learn: 1195.4686829	test: 1530.2223534	best: 1530.0235049 (952)	total: 4m 18s	remaining: 1.3s
# 995:	learn: 1195.3837850	test: 1530.1893351	best: 1530.0235049 (952)	total: 4m 19s	remaining: 1.04s
# 996:	learn: 1195.2737839	test: 1530.1785644	best: 1530.0235049 (952)	total: 4m 19s	remaining: 781ms
# 997:	learn: 1195.1501972	test: 1530.1874417	best: 1530.0235049 (952)	total: 4m 19s	remaining: 521ms
# 998:	learn: 1194.9723201	test: 1530.2303079	best: 1530.0235049 (952)	total: 4m 20s	remaining: 260ms
# 999:	learn: 1194.9137006	test: 1530.2264139	best: 1530.0235049 (952)	total: 4m 20s	remaining: 0us
#
# bestTest = 1530.023505
# bestIteration = 952

# %% [markdown]
# Обучим модель, при которой обеспечен минимум метрики RMSE - 1534:

# %%
# %%time

model = CatBoostRegressor(cat_features=cat_features,
                          learning_rate = 0.1,
                          depth = 10,
                          random_state = 1049,
                          verbose=100)
model.fit(features_train,target_train)
# Out:
# 0:	learn: 4274.3974413	total: 399ms	remaining: 6m 38s
# 100:	learn: 1574.6944241	total: 30.1s	remaining: 4m 28s
# 200:	learn: 1493.6761713	total: 1m 1s	remaining: 4m 3s
# 300:	learn: 1443.0665896	total: 1m 32s	remaining: 3m 35s
# 400:	learn: 1400.4511313	total: 2m 4s	remaining: 3m 6s
# 500:	learn: 1367.0312138	total: 2m 36s	remaining: 2m 35s
# 600:	learn: 1338.6098272	total: 3m 8s	remaining: 2m 5s
# 700:	learn: 1312.7027326	total: 3m 40s	remaining: 1m 34s
# 800:	learn: 1290.3797701	total: 4m 12s	remaining: 1m 2s
# 900:	learn: 1272.6475154	total: 4m 45s	remaining: 31.3s
# 999:	learn: 1255.8651641	total: 5m 16s	remaining: 0us
# CPU times: user 5min 17s, sys: 1.07 s, total: 5min 18s
# Wall time: 5min 19s

# %%
# %%time
predictions_CBR = model.predict(features_valid)
mse = mean_squared_error(target_valid, predictions_CBR)
rmse = mse ** 0.5
print(rmse)
# Out:
# 1536.4182641522734
# CPU times: user 857 ms, sys: 4.08 ms, total: 861 ms
# Wall time: 859 ms

# %% [markdown]
# Модель показала лучшую метрику по сравнению с LGBMRegressor, но обучалась значительно дольше.

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# ### Сравнение моделей

# %% [markdown]
# Сравним результаты, которые показали модели на валидационной выборке:

# %%
result_data = {'fit time':['689 ms','7.2 s','5 min 19 s'],
              'predictions time':['71.8 ms','415 ms','859 ms'],
             'rmse':[1797,1557,1536]}
results_data = pd.DataFrame(result_data, index =['DecisionTreeRegressor', 'LGBMREgressor', 'CatBoostRegressor'])
results_data
# Out:
#                          fit time predictions time  rmse
# DecisionTreeRegressor      689 ms          71.8 ms  1797
# LGBMREgressor               7.2 s           415 ms  1557
# CatBoostRegressor      5 min 19 s           859 ms  1536

# %% [markdown]
# Заказчику важны сразу несколько параметров, а модели дали не однозначный вариант.

# %% [markdown]
# Для быстрых решений с очень приблизительной точностью подойдет DecisionTreeRegressor. Это модель быстро обучается, и дает приблизительную стоимость автомобиля.
#
# Для более точных решений можно использовать как LGBMRegressor, так и CatBoostRegressor. Первый быстрее обучается, но дает меньшую точность, второй — требует временя на обучение и предсказание, но имеет более высокую точность.

# %% [markdown]
# В целом, когда дело касается денег, лучше не спешить — а потому лучшей нам кажется модель CatBoostRegressor. Проверим ее работу на тестовой выборке для объективной проверки качества ее работы.

# %% [markdown]
# ### Проверка работы модели на тестовой выборке

# %% [markdown]
# Повторно проверим точность предсказаний и засечем время обучения CatBoostRegressor. Категориальные признаки уже определены.

# %%
# %%time

model_CBR = CatBoostRegressor(cat_features=cat_features,
                              learning_rate = 0.1,
                              depth = 10,
                              l2_leaf_reg = 1,
                              random_state = 1049,
                              verbose=False)
model_CBR.fit(features_train,target_train)
# Out:
# CPU times: user 5min 28s, sys: 1.29 s, total: 5min 29s
# Wall time: 5min 31s

# %%
# %%time

predictions_CBR = model_CBR.predict(features_test)
mse = mean_squared_error(target_test, predictions_CBR)
rmse = mse ** 0.5
print(rmse)
# Out:
# 1532.6367864596314
# CPU times: user 1.09 s, sys: 4.03 ms, total: 1.1 s
# Wall time: 1.1 s

# %% [markdown]
# Среднеквадратическая ошибка на тестовой выборке 1532 евро — не идеальный результат, но наверняка позволит выявить явно мошеннические схемы сервису, а пользователям

# %% [markdown]
# ### Вывод

# %% [markdown]
# В ходе работы:
#
# - были загружены данные и проведена их предобработка;
# - выполнено обучение моделей с использованием различных наборов гиперпараметров;
# - модели разных типов с лучшими гиперпараметрами проверены на валидационной выборке;
# - работа модели CatBoostRegressor, показавшей наиболее точный результат была проверена на тестовой выборке.
